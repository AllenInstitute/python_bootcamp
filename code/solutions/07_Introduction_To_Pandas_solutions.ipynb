# %% [markdown]
# <div class="none" style="">
# <img src="../support_files/images/swdb_logo.jpg">
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <center><h1>Introduction to Pandas</h1></center>
#
#
# **<code>[pandas](https://pandas.pydata.org/)</code>** is a library with high-level data structures and manipulation tools:
#
# **DataFrame Object**
#
# A Pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure that holds ***relational data***.
#
# Data is aligned in a tabular fashion with labeled rows and columns like a spreadsheet or SQL table, or a dict of Series objects. Essentially, a Pandas DataFrame consists of three components, the data, rows, and columns.
# ***
# Key takeaways:
# * Represents a tabular, spreadsheet-like data structure
# * Ordered collection of columns
# * Each column can be a different value type (numeric, string, boolean, etc.)
# * holds relational data
#
# <img src="../support_files/images/pandas/dataframe_example.png">
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <center><h1>Relational Data</h1></center>
#
# Pandas dataframes/tables typically contain relational data. Relational data is data that captures associations or relationships between data points. This is often expressed as a table with columns indicating the quantities related. For example, "First names" are associated with "Last Names".
#
#
# This is a table with two columns, one column for First Name and one column for Last Name. For the pedantic, a "relation" is a table with no duplicate entries.
#
# <img src="../support_files/images/pandas/pandas_relational_df.png" width='250'>
#
# This is a table with two columns, one column for First Name and one column for Last Name.
#
#
# For the pedantic, a "relation" is a table with no duplicate entries.  We might, for example, have two John Smiths.  We can try to eliminate this collision problem by introducing an **Index**.
#
# <img src="../support_files/images/pandas/pandas_student_df_with_index.png" width='300'>
#
# **A brief note on row vs index**
# In this notebook and lecture we will use the terms row number and index. For many contexts these terms are interchangable, however due to pandas nomenclature around different ways of slicing and dicing data, we will have distinct meanings for these
#
# row number: the number of the row starting with row 0
# index: label given to a specific row
#
#
# <img src="../support_files/images/pandas/pandas_relation_df_generic.png" width='250'>
#
# In the above table we have added an "Index".  The `DataFrame` object in Python is a representation of a table with these components.  It is composed of rows, each with an index, and labeled columns.
#
# <br>
# In a general `DataFrame`, we might have many different relations captured in the same table.  For example, a `DataFrame` with student data from a school might look something like this:
#
# <img src="../support_files/images/pandas/pandas_relational_student_df.png" width='500'>
#
# <br>
#
# **Data Representation**
#
# When thinking about data analysis, note that the above table already gives us something to think about regarding how choices of data representation affect conclusions.  What if someone only has one name?  What if they have a name that isn't easily represented as "First name/Last name"?  What if they come from a culture that keeps track of multiple names?
#
# Note there is a Gender column.  What if the person who constructed this data had created this column as `isFemale`?
#
# When interacting with tables and `DataFrames`, it is important to keep these issues in mind.  Structural choices about data can and will affect conclusions.  Whenever you make a `DataFrame` or use one someone else has constructed for you, you are making or dealing with these kinds of choices.
#
# There are standard operations related to questions you might have about the students in the above `DataFrame`.
# <ul>
#     <li> Which students took Physics?  </li>
#     <li> Which students got an A in any course?  Which Students from the University of Washington got an A or B in either Physics or History? </li>
#     </ul>
#
# The `DataFrame` object has operations that allow these kinds of questions to be answered in a computationally efficient manner. These are covered in this tutorial.
#
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <center><h2>Many different relations</h2></center>
#
# If we only needed to subselect from one table, we wouldn't really need something like `pandas` and its `DataFrame` (though it is helpful for this!).  The real power of the `DataFrame` object appears when we have multiple relations, i.e. multiple `DataFrame`s and we wish to combine them in some way.
#
# For example we might have `DataFrame`s that represent student Grades, or Professors, or Schools.
#
# <img src="../support_files/images/pandas/pandas_grade_df.png" width='200'>
#
# or a `DataFrame` with Courses offered by Departments in different schools:
#
# <img src="../support_files/images/pandas/pandas_departments_df.png" width='500'>
#
# or a `DataFrame` of Professors and the Courses they teach
#
# <img src="../support_files/images/pandas/pandas_professors.png" width='500'>
#
#
#
# The main purpose of `pandas` and the `DataFrame` object is to allow us to ask questions across multiple sets of relations.
#
#
# <ul>
#     <li>What is the average score of students of course Y from professor X (who may have taught at different institutions….)?</li>
#     <li>What is the average number of students at school X from State Y?</li>
#     <li>What is the distribution of grades from students in Biology whose home town is Y?</li>
# </ul>
#
#
#
#
# `DataFrames` have powerful tools like `merge` to combine information from multiple `DataFrame`s that allow you to ask these kinds of questions quickly and easily.
#
# Let's get started!
#
# </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='why_use_pandas'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h2>Why Use Pandas</h2>
#
# **Annotated Data is Powerful!**
#
# Because pandas combines data labels with values it facilitites easy:
# * dataset exploration
# * dataset visualization
# * basic statistical analysis
#
# <br/>
#
# **Data manipulation is easy!**
#
# Pandas takes the functionality of slicing & dicing data and layers in many other helpful features that help with:
# * cleaning data
#     * Column headers are descriptive not numerical.
#     * Columns hold single variables.
#     * Variables are stored in either rows or columns, not both.
#     * handling missing or invalid values
# * data wrangling
#     * getting the data into a structure that facilitates your analysis
# * easily loading and saving data
#     * load many formats of data and save in many formats
#
#
# <br/>
#
# **High Level Data manipulation**
#
# Pandas supports vectorized mathematical operations which optimizes computation performance and execution speed. Additionally the 2D labeled tabular structure of a pandas dataframe allows other high level manipulations such as:
# * data grouping aggregation
# * table manipulations (transforming rows to columns &/or columns to rows)
# * Merging or Joinng multiple dataframes/tables</div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='pandas_resources'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
#
# **Documentation & Resources**
#
# This introduction will only just scratch the surface of Pandas functionality. For more information, check out the [full documentation](https://pandas.pydata.org/docs/reference/index.html)
#
# This [cheat-sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) is also highly recommended to print out and keep handy as a resource.
# <p>Or check out the <a href="http://pandas.pydata.org/pandas-docs/stable/10min.html">'10 minutes to Pandas'</a> tutorial here (note: title may mischaracterize time investment).</div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <center><h2>Table of Contents & Jumplinks</h2></center>
# <h4><a href='#introduction'>Introduction</a></h4>
# <li>Intro to Pandas and Dataframes
# <li>Intro Relational Data
# <li>why use pandas
# <li>resources & documentation
#
# <h4><a href='#imports'>Imports</a></h4>
# <h4><a href='#dataload'>Data Loading</a></h4>
#
# <h4><a href='#explore'>Explore the dataset & basic functionality</a></h4>
# <li>view the dataframe, how many rows & columns
# <li>view specifics about columns
# <li>get data types and unique entries
# <li>descriptive statistics
#
# <h4><a href='#dataselection'>Data Selection, slicing & dicing</a></h4>
# <li>select data by labels/names
# <li>select data by position
# <li>“views” vs copies of the data
# <li>conditional selection
# <li>multiple condition selection
#
#
# <h4><a href='#manipulate'>Table & Data Manipulation</a></h4>
# <li>add/create new columns
# <li>drop columns
# <li>sort values
#
# <h4><a href='#plot'>Table transformation, aggregation & plotting</a></h4>
# <li>wide vs long tables
# <li>melt (transform wide to long df)
# <li>pivot (transform long to wide df)
# <li>cross tab (aggregate counts)
# <li>pivot_table (flexible aggregation)
# <li>groupby & agg
#
# <h4><a href='#table'>Create new tables, join tables, save tables</a></h4>
# <li>join & merge tables
# <li>create dataframe from scratch
# <li>saving dataframes
# </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='imports'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h2> Import Packages </h2> </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# **Library imports**
# Here we'll load in the libraries we'll use to shape and explore the data</div>

# %%
import os
import numpy as np

# %%
# import `pandas` and give it a short name `pd` since we will type it very frequently.
import pandas as pd

# %% [markdown]
# <div class="none" style="">
#
# <a id='dataload'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h2> Load dataset </h2>
#
# Our first step is loading in the data from a file
#
# Pandas has great [tools for automatically interpretting data from many sources](https://pandas.pydata.org/docs/reference/io.html)
#
# * [pd.read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
# * [pd.read_feather](https://pandas.pydata.org/docs/reference/api/pandas.read_feather.html)
# * pd.read_excel
# * pd.read_pickle
# * pd.read_json
#
#  we will use pd.read_feather</div>

# %%
filepath = os.path.join('../support_files', 'datasets', 'messy_superstore_data.feather')
df = pd.read_feather(filepath)

# ignore this line of code for now- it will be explained a bit later
df.set_index('Row ID', inplace = True)

# %% [markdown]
# <div class="none" style="">
#
# <a id='explore'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h2> Explore the dataset </h2>
#
# <h3> Internal links </h3>
#
# **basic data exploration**
#
# * <a href='#df'>view dataframe "preview"</a>
# * <a href='#.head()'> view rows from beginning or end of dataframe (df.head, df.tail)</a>
# * <a href='#shape'>get dataframe shape and length(len, np.shape)</a>
# * <a href='#.columns'>list all columns(.columns)</a>
# * <a href='#dtypes'>get column data types(.dtypes)</a>
#
# **basic data visualization**
#
#
# **descriptive statistics**
# * <a href='#describe'> get table level descriptive statistics</a>
#
#
# **Bonus Material**
# (found at end of notebook)
#
# </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='df'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>view the dataframe</h4>
#
# simply calling the dataframe ('df' or whatever you've named the dataframe) gives a preview view of the dataframe/table
# * shows the first 5 and last 5 rows of data
# * shows the first 10 and last 10 columns of data
# </div>

# %%
df
# Out:
#                     Order ID      Segment    Category  Category (OLD)  \
# Row ID
# IN-2014-23218  IN-2014-75456     Consumer   FURNITURE             NaN
# IN-2014-24599  IN-2014-29767  Home Office   FURNITURE             NaN
# IN-2014-24597  IN-2014-29767  Home Office   FURNITURE             NaN
# IN-2014-27993  IN-2014-20415  Home Office   FURNITURE             NaN
# IN-2014-28967  IN-2014-47337    Corporate   FURNITURE             NaN
# ...                      ...          ...         ...             ...
# ZA-2014-49187   ZA-2014-9750    Corporate  TECHNOLOGY             NaN
# ZI-2014-42069   ZI-2014-7610    Corporate  TECHNOLOGY             NaN
# ZI-2014-43712   ZI-2014-5970  Home Office  TECHNOLOGY             NaN
# ZI-2014-48372   ZI-2014-9550     Consumer  TECHNOLOGY             NaN
# ZI-2014-48014   ZI-2014-3570     Consumer  TECHNOLOGY             NaN
#
#               Sub-Category                     Product Name        Product ID  \
# Row ID
# IN-2014-23218  FURNISHINGS  Rubbermaid Door Stop, Erganomic   FUR-FU-10004064
# IN-2014-24599    BOOKCASES  Ikea Library with Doors, Mobile   FUR-BO-10001255
# IN-2014-24597  FURNISHINGS  Rubbermaid Door Stop, Erganomic   FUR-FU-10004064
# IN-2014-27993    BOOKCASES      Bush Classic Bookcase, Pine   FUR-BO-10002204
# IN-2014-28967       CHAIRS           Hon Rocking Chair, Red   FUR-CH-10003965
# ...                    ...                              ...               ...
# ZA-2014-49187  ACCESSORIES              Memorex Router, USB  TEC-MEM-10002202
# ZI-2014-42069     MACHINES              StarTech Phone, Red  TEC-STA-10000699
# ZI-2014-43712  ACCESSORIES               Belkin Router, USB  TEC-BEL-10003985
# ZI-2014-48372     MACHINES      Konica Receipt Printer, Red  TEC-KON-10003116
# ZI-2014-48014     MACHINES          Okidata Calculator, Red  TEC-OKI-10001433
#
#                    Country  Market        Region  ...  12/1/2014  8/1/2014  \
# Row ID                                            ...
# IN-2014-23218  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-24599  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-24597  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-27993  Afghanistan    APAC  Central Asia  ...        NaN   2070.15
# IN-2014-28967  Afghanistan    APAC  Central Asia  ...     914.34       NaN
# ...                    ...     ...           ...  ...        ...       ...
# ZA-2014-49187       Zambia  Africa        Africa  ...        NaN       NaN
# ZI-2014-42069     Zimbabwe  Africa        Africa  ...        NaN       NaN
# ZI-2014-43712     Zimbabwe  Africa        Africa  ...        NaN       NaN
# ZI-2014-48372     Zimbabwe  Africa        Africa  ...      71.64       NaN
# ZI-2014-48014     Zimbabwe  Africa        Africa  ...        NaN       NaN
#
#                5/1/2014 3/1/2014 4/1/2014 2/1/2014  6/1/2014      City  \
# Row ID
# IN-2014-23218       NaN      NaN      NaN      NaN       NaN     Kabul
# IN-2014-24599       NaN  731.820      NaN      NaN       NaN     Herat
# IN-2014-24597       NaN  169.680      NaN      NaN       NaN     Herat
# IN-2014-27993       NaN      NaN      NaN      NaN       NaN     Kabul
# IN-2014-28967       NaN      NaN      NaN      NaN       NaN     Kabul
# ...                 ...      ...      ...      ...       ...       ...
# ZA-2014-49187       NaN      NaN      NaN   246.42       NaN     Ndola
# ZI-2014-42069       NaN   21.501      NaN      NaN       NaN  Bulawayo
# ZI-2014-43712       NaN      NaN      NaN      NaN    77.688  Bulawayo
# ZI-2014-48372       NaN      NaN      NaN      NaN       NaN  Bulawayo
# ZI-2014-48014       NaN      NaN      NaN      NaN       NaN    Harare
#
#                     State                                      manufacturers
# Row ID
# IN-2014-23218       Kabul  [Dunder Mifflin, Globex Corp, Hudsucker Indust...
# IN-2014-24599       Hirat  [ACME Co, Buy n Large, Dunder Mifflin, Globex ...
# IN-2014-24597       Hirat  [Dunder Mifflin, LexCorp, Olivander Crafts, Ro...
# IN-2014-27993       Kabul                 [Dunder Mifflin, Olivander Crafts]
# IN-2014-28967       Kabul  [ACME Co, Buy n Large, Dunder Mifflin, LexCorp...
# ...                   ...                                                ...
# ZA-2014-49187  Copperbelt     [ACME Co, Royco Waystar, Umbrella Corporation]
# ZI-2014-42069    Bulawayo                                   [Dunder Mifflin]
# ZI-2014-43712    Bulawayo       [ACME Co, Buy n Large, Hudsucker Industries]
# ZI-2014-48372    Bulawayo                       [ACME Co, Wayne Enterprises]
# ZI-2014-48014      Harare  [Dunder Mifflin, Olivander Crafts, Royco Wayst...
#
# [17531 rows x 34 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='.head()'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>View the first or last n rows</h4>
#
# **[.head()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)**: shows the first n rows
#
# **[.tail()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)**: shows the last n rows
#
# * <code>df.head()</code> and <code>df.tail()</code> shows 5 rows of data by default
# * adding a number <code>df.head(n)</code> adjusts the number of rows shown</div>

# %%
# show the first 8 rows
df.head(8)
# Out:
#                     Order ID      Segment   Category  Category (OLD)  \
# Row ID
# IN-2014-23218  IN-2014-75456     Consumer  FURNITURE             NaN
# IN-2014-24599  IN-2014-29767  Home Office  FURNITURE             NaN
# IN-2014-24597  IN-2014-29767  Home Office  FURNITURE             NaN
# IN-2014-27993  IN-2014-20415  Home Office  FURNITURE             NaN
# IN-2014-28967  IN-2014-47337    Corporate  FURNITURE             NaN
# AG-2014-50986   AG-2014-2760     Consumer  FURNITURE             NaN
# AG-2014-50983   AG-2014-2760     Consumer  FURNITURE             NaN
# AG-2014-49384   AG-2014-2040     Consumer  FURNITURE             NaN
#
#               Sub-Category                     Product Name        Product ID  \
# Row ID
# IN-2014-23218  FURNISHINGS  Rubbermaid Door Stop, Erganomic   FUR-FU-10004064
# IN-2014-24599    BOOKCASES  Ikea Library with Doors, Mobile   FUR-BO-10001255
# IN-2014-24597  FURNISHINGS  Rubbermaid Door Stop, Erganomic   FUR-FU-10004064
# IN-2014-27993    BOOKCASES      Bush Classic Bookcase, Pine   FUR-BO-10002204
# IN-2014-28967       CHAIRS           Hon Rocking Chair, Red   FUR-CH-10003965
# AG-2014-50986  FURNISHINGS  Deflect-O Light Bulb, Erganomic  FUR-DEF-10002865
# AG-2014-50983       CHAIRS     Novimex Rocking Chair, Black  FUR-NOV-10002453
# AG-2014-49384  FURNISHINGS        Rubbermaid Frame, Durable  FUR-RUB-10003004
#
#                    Country  Market        Region  ...  12/1/2014  8/1/2014  \
# Row ID                                            ...
# IN-2014-23218  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-24599  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-24597  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-27993  Afghanistan    APAC  Central Asia  ...        NaN   2070.15
# IN-2014-28967  Afghanistan    APAC  Central Asia  ...     914.34       NaN
# AG-2014-50986      Algeria  Africa        Africa  ...        NaN       NaN
# AG-2014-50983      Algeria  Africa        Africa  ...        NaN       NaN
# AG-2014-49384      Algeria  Africa        Africa  ...        NaN       NaN
#
#                5/1/2014 3/1/2014 4/1/2014 2/1/2014  6/1/2014     City  State  \
# Row ID
# IN-2014-23218       NaN      NaN      NaN      NaN       NaN    Kabul  Kabul
# IN-2014-24599       NaN   731.82      NaN      NaN       NaN    Herat  Hirat
# IN-2014-24597       NaN   169.68      NaN      NaN       NaN    Herat  Hirat
# IN-2014-27993       NaN      NaN      NaN      NaN       NaN    Kabul  Kabul
# IN-2014-28967       NaN      NaN      NaN      NaN       NaN    Kabul  Kabul
# AG-2014-50986       NaN      NaN      NaN      NaN     17.61    Saida  Saida
# AG-2014-50983       NaN      NaN      NaN      NaN    516.00    Saida  Saida
# AG-2014-49384       NaN      NaN      NaN      NaN       NaN  Algiers  Alger
#
#                                                    manufacturers
# Row ID
# IN-2014-23218  [Dunder Mifflin, Globex Corp, Hudsucker Indust...
# IN-2014-24599  [ACME Co, Buy n Large, Dunder Mifflin, Globex ...
# IN-2014-24597  [Dunder Mifflin, LexCorp, Olivander Crafts, Ro...
# IN-2014-27993                 [Dunder Mifflin, Olivander Crafts]
# IN-2014-28967  [ACME Co, Buy n Large, Dunder Mifflin, LexCorp...
# AG-2014-50986  [ACME Co, Hudsucker Industries, Wayne Enterpri...
# AG-2014-50983             [Dunder Mifflin, Umbrella Corporation]
# AG-2014-49384  [Buy n Large, Hudsucker Industries, LexCorp, R...
#
# [8 rows x 34 columns]

# %%
# show the last 7 rows
df.tail(7)
# Out:
#                    Order ID      Segment    Category  Category (OLD)  \
# Row ID
# ZA-2014-50068  ZA-2014-6660  Home Office  TECHNOLOGY             NaN
# ZA-2014-50069  ZA-2014-6660  Home Office  TECHNOLOGY             NaN
# ZA-2014-49187  ZA-2014-9750    Corporate  TECHNOLOGY             NaN
# ZI-2014-42069  ZI-2014-7610    Corporate  TECHNOLOGY             NaN
# ZI-2014-43712  ZI-2014-5970  Home Office  TECHNOLOGY             NaN
# ZI-2014-48372  ZI-2014-9550     Consumer  TECHNOLOGY             NaN
# ZI-2014-48014  ZI-2014-3570     Consumer  TECHNOLOGY             NaN
#
#               Sub-Category                        Product Name  \
# Row ID
# ZA-2014-50068      COPIERS  Brother Fax and Copier, High-Speed
# ZA-2014-50069      COPIERS     Hewlett Fax Machine, High-Speed
# ZA-2014-49187  ACCESSORIES                 Memorex Router, USB
# ZI-2014-42069     MACHINES                 StarTech Phone, Red
# ZI-2014-43712  ACCESSORIES                  Belkin Router, USB
# ZI-2014-48372     MACHINES         Konica Receipt Printer, Red
# ZI-2014-48014     MACHINES             Okidata Calculator, Red
#
#                      Product ID   Country  Market  Region  ...  12/1/2014  \
# Row ID                                                     ...
# ZA-2014-50068  TEC-BRO-10003401    Zambia  Africa  Africa  ...        NaN
# ZA-2014-50069  TEC-HEW-10002304    Zambia  Africa  Africa  ...        NaN
# ZA-2014-49187  TEC-MEM-10002202    Zambia  Africa  Africa  ...        NaN
# ZI-2014-42069  TEC-STA-10000699  Zimbabwe  Africa  Africa  ...        NaN
# ZI-2014-43712  TEC-BEL-10003985  Zimbabwe  Africa  Africa  ...        NaN
# ZI-2014-48372  TEC-KON-10003116  Zimbabwe  Africa  Africa  ...      71.64
# ZI-2014-48014  TEC-OKI-10001433  Zimbabwe  Africa  Africa  ...        NaN
#
#                8/1/2014  5/1/2014 3/1/2014 4/1/2014 2/1/2014  6/1/2014  \
# Row ID
# ZA-2014-50068       NaN       NaN      NaN      NaN   189.69       NaN
# ZA-2014-50069       NaN       NaN      NaN      NaN   318.12       NaN
# ZA-2014-49187       NaN       NaN      NaN      NaN   246.42       NaN
# ZI-2014-42069       NaN       NaN   21.501      NaN      NaN       NaN
# ZI-2014-43712       NaN       NaN      NaN      NaN      NaN    77.688
# ZI-2014-48372       NaN       NaN      NaN      NaN      NaN       NaN
# ZI-2014-48014       NaN       NaN      NaN      NaN      NaN       NaN
#
#                    City       State  \
# Row ID
# ZA-2014-50068    Lusaka      Lusaka
# ZA-2014-50069    Lusaka      Lusaka
# ZA-2014-49187     Ndola  Copperbelt
# ZI-2014-42069  Bulawayo    Bulawayo
# ZI-2014-43712  Bulawayo    Bulawayo
# ZI-2014-48372  Bulawayo    Bulawayo
# ZI-2014-48014    Harare      Harare
#
#                                                    manufacturers
# Row ID
# ZA-2014-50068  [Buy n Large, LexCorp, Olivander Crafts, Umbre...
# ZA-2014-50069  [Buy n Large, Globex Corp, Hudsucker Industrie...
# ZA-2014-49187     [ACME Co, Royco Waystar, Umbrella Corporation]
# ZI-2014-42069                                   [Dunder Mifflin]
# ZI-2014-43712       [ACME Co, Buy n Large, Hudsucker Industries]
# ZI-2014-48372                       [ACME Co, Wayne Enterprises]
# ZI-2014-48014  [Dunder Mifflin, Olivander Crafts, Royco Wayst...
#
# [7 rows x 34 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='shape'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Get the shape and length of the dataframe</h4>
#
# beause pandas is built off of numpy, many familiar functions/methods work with DataFrames
#
# * **[numpys shape function](https://numpy.org/doc/stable/reference/generated/numpy.shape.html)** can give the dimensions of a dataframe
#     * <code>df.shape</code> - returns (rows, columns)
# * **[len()](https://docs.python.org/3/library/functions.html#len)** - the built in python function will return the number of rows in a dataframe
#     * <code>len(df)</code></div>

# %%
df.shape
# Out:
# (17531, 34)

# %%
len(df)
# Out:
# 17531

# %% [markdown]
# <div class="none" style="">
#
# <a id='.columns'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h4>List Columns</h4>
#
# **[.columns](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html)** provides a list of the column labels for a dataframe
#
# <code>df.columns</code></div>

# %%
# lets try it out
df.columns
# Out:
# Index(['Order ID', 'Segment', 'Category', 'Category (OLD)', 'Sub-Category',
#        'Product Name', 'Product ID', 'Country', 'Market', 'Region', 'Quantity',
#        'Discount', 'Profit', 'Customer ID', 'Customer Name', 'Order Priority',
#        'Postal Code', 'Ship Mode', 'Shipping Cost', '10/1/2014', '7/1/2014',
#        '11/1/2014', '9/1/2014', '1/1/2014', '12/1/2014', '8/1/2014',
#        '5/1/2014', '3/1/2014', '4/1/2014', '2/1/2014', '6/1/2014', 'City',
#        'State', 'manufacturers'],
#       dtype='str')

# %% [markdown]
# <div class="none" style="">
#
# <a id='dtypes'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h4>Show data from a single column</h4>
#
# Like retrieving a value from a dictionary, we can get the data for a single column by indexing with the column's name:
# </div>

# %%
df['Country']
# Out:
# Row ID
# IN-2014-23218    Afghanistan
# IN-2014-24599    Afghanistan
# IN-2014-24597    Afghanistan
# IN-2014-27993    Afghanistan
# IN-2014-28967    Afghanistan
#                     ...
# ZA-2014-49187         Zambia
# ZI-2014-42069       Zimbabwe
# ZI-2014-43712       Zimbabwe
# ZI-2014-48372       Zimbabwe
# ZI-2014-48014       Zimbabwe
# Name: Country, Length: 17531, dtype: str

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4> Get column or element data types</h4>
#
# * **[.dtypes](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html)** : lists the data type for all columns in a dataframe
#     * <code>df.dtypes</code>
#
# * **type()** allows inspection of data type for a specific element (i.e. specific row & column)
#     * This can be helpful if the .dtypes function returns "object"
#     * <code>type(df['column'][row number])</code></div>

# %%
df.dtypes
# Out:
# Order ID              str
# Segment               str
# Category              str
# Category (OLD)    float64
# Sub-Category          str
# Product Name          str
# Product ID            str
# Country               str
# Market                str
# Region                str
# Quantity          float64
# Discount          float64
# Profit            float64
# Customer ID           str
# Customer Name         str
# Order Priority        str
# Postal Code       float64
# Ship Mode             str
# Shipping Cost     float64
# 10/1/2014         float64
# 7/1/2014          float64
# 11/1/2014         float64
# 9/1/2014          float64
# 1/1/2014          float64
# 12/1/2014         float64
# 8/1/2014          float64
# 5/1/2014          float64
# 3/1/2014          float64
# 4/1/2014          float64
# 2/1/2014          float64
# 6/1/2014          float64
# City                  str
# State                 str
# manufacturers      object
# dtype: object

# %%
# use the built in type() function to get the first row of the "Category" column
type(df["Category"]['ZA-2014-50068'])
# Out:
# str

# %% [markdown]
# <div class="none" style="">
#
# <a id='unique'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4> get unique entries for a column</h4>
#
# **<code>[.unique](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#how-do-i-select-specific-columns-from-a-dataframe)</code>**
#
#
# <code>df['column_name'].unique()</code>   returns an array of all unique entries</div>

# %%
# get all unique entries for the Country column

df['Country'].unique()
# Out:
# <ArrowStringArray>
# [         'Afghanistan',              'Algeria',               'Angola',
#             'Argentina',            'Australia',              'Austria',
#            'Azerbaijan',           'Bangladesh',             'Barbados',
#               'Belarus',
#  ...
#                 'Qatar',         'Sierra Leone',             'Slovakia',
#             'Sri Lanka',               'Taiwan',           'Tajikistan',
#   'Trinidad and Tobago', 'United Arab Emirates',          'South Sudan',
#             'Swaziland']
# Length: 138, dtype: str

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 1) What are the unique values for the Market column?
#
# 2) Identify the data type for the Product ID column
# </div>

# %%
# Answer 1:
df['Market'].unique()
# Out:
# <ArrowStringArray>
# ['APAC', 'Africa', 'LATAM', 'EU', 'EMEA', 'Canada', 'US']
# Length: 7, dtype: str

# %%
# Answer 2:
type(df["Product ID"])
# Out:
# pandas.Series

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Plotting with Pandas!</h4>
#
# Pandas has a set of plotting tools built into the library. You can quickly create visualizations(especially with grouped and aggregated data which we will get to later) using pandas built in plotting functions such as:
#
#
# * **<code>[.plot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)</code>**
#     * example:
#
#         df.plot(x = 'xcolumn',
#             y= 'ycolumn',
#             kind = "box",
#             xlabel= 'x value units',
#             ylabel = 'y value units')
#
#
# * **<code>[.boxplot](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html)</code>**
#
#
# **NOTE!** Pandas works especially well with the the seaborn plotting package. We won't cover this now because there's a whole data visualization tutorial later!
#      </div>

# %%
# Lets create a boxplot of  profit by category

df.boxplot(column=['Profit'], by=['Category'])
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Category]'>

# %% [markdown]
# <div class="none" style="">
#
# <a id='describe'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>get descriptive statistics</h4>
#
#
# Descriptive statistic are summary statistics that quantitatively describes or summarizes features from a collection of information or dataset. This typically included things like sample size, measures of central tendency (mean, median, mode), measures of variability or dispersion (standard deviation, min, max, kurtosis, skewness)
#
#
# **<code>[.describe()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)</code>** will return descriptive statistics for all quantitative columns of a dataframe
#
# <img src="../support_files/images/pandas/pandas_describe.png">
#
# <code>df.describe()</code>
#
# For each numerical column the following descriptive statitsics are provided:
# * count
# * mean
# * standard deviation
# * minimum
# * 25, 50 & 75th percentiles
# * max </div>

# %%
df.describe()
# Out:
#        Category (OLD)      Quantity      Discount        Profit   Postal Code  \
# count             0.0  17531.000000  17531.000000  17531.000000   3321.000000
# mean              NaN      3.457989      0.143291     28.758540  56192.587775
# std               NaN      2.290856      0.211830    174.283412  31977.397359
# min               NaN      1.000000      0.000000  -3839.990400   1841.000000
# 25%               NaN      2.000000      0.000000      0.000000  28110.000000
# 50%               NaN      3.000000      0.000000      9.200000  60440.000000
# 75%               NaN      5.000000      0.200000     36.808500  90032.000000
# max               NaN     14.000000      0.800000   6719.980800  99301.000000
#
#        Shipping Cost     10/1/2014     7/1/2014     11/1/2014     9/1/2014  \
# count   17531.000000   1626.000000  1087.000000   2147.000000  2018.000000
# mean       26.268085    260.004077   237.999706    258.630194   238.432727
# std        56.545260    543.523703   433.300176    520.039000   463.761215
# min         0.010000      0.990000     1.080000      1.197000     1.359000
# 25%         2.570000     31.491000    27.225000     30.840000    26.793000
# 50%         7.720000     87.940000    78.327000     90.936000    79.620000
# 75%        24.455000    267.678000   244.147500    269.190000   244.085000
# max       867.690000  11199.968000  4001.040000  10499.970000  7958.580000
#
#           1/1/2014    12/1/2014     8/1/2014     5/1/2014      3/1/2014  \
# count   918.000000  2153.000000  1675.000000  1284.000000   1068.000000
# mean    262.819777   233.694238   272.608921   224.611407    246.349038
# std     528.201441   432.184769   502.542821   396.292046    593.698325
# min       2.040000     1.161000     1.584000     1.188000      0.556000
# 25%      27.412500    30.360000    36.984000    30.105000     32.202000
# 50%      83.912400    79.120000    99.870000    79.425000     83.788800
# 75%     263.491500   232.880000   284.043000   226.730000    246.533625
# max    5443.960000  4864.320000  5211.120000  4298.850000  13999.960000
#
#           4/1/2014     2/1/2014     6/1/2014
# count  1051.000000   756.000000  1748.000000
# mean    230.991305   244.493857   229.870745
# std     442.449941   399.022820   423.420032
# min       1.188000     1.788000     0.444000
# 25%      28.545000    35.460000    29.467500
# 50%      79.140000    93.765000    79.960000
# 75%     234.338000   275.121000   239.477925
# max    4799.984000  3425.400000  5486.670000

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>other built in summary statistic functions</h4>
#
# Pandas also provides a large set of summary functions that can operate on different kinds of pandas objects (dataframe columns, Series, Groupby etc.)
#
# * **<code>[.count()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.count.html?highlight=count#pandas.DataFrame.count)</code>**
# * **<code>[.sum()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html?highlight=sum#pandas.DataFrame.sum)</code>**
# * **<code>[.min()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.min.html?highlight=min#pandas.DataFrame.min)</code>**
# * **<code>[.max()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.max.html?highlight=max#pandas.DataFrame.max)</code>**
# * **<code>[.mean()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html?highlight=mean#pandas.DataFrame.mean)</code>**
# * **<code>[.median()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.median.html?highlight=median#pandas.DataFrame.median)</code>**
# * **<code>[.var()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.var.html?highlight=var#pandas.DataFrame.var)</code>**
# * **<code>[.std()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.std.html?highlight=std#pandas.DataFrame.std)</code>**
#
# These functions become especially useful in the next section where there might be some specific selection of  data you want to analyze </div>

# %%
# lets do a very quick demonstration of how this works
# here we get the mean discount for the entire discount column
df["Discount"].mean()
# Out:
# np.float64(0.1432911984484627)

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISE:**
#
# What is the maximum value in the Shipping Cost column?
# </div>

# %%
df['Shipping Cost'].max()
# Out:
# np.float64(867.69)

# %% [markdown]
# <div class="none" style="">
#
# <a id='dataselection'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h2> Data Selection, Slicing & Dicing </h2>
#
# <h3> Internal Links </h3>
#
# **basic data selection & filtering**
# * <a href='#column_selection'>column selection</a>
# * <a href='#view_vs_copy'>'view' of data vs a copy</a>
# * <a href='#loc'>select data by labels/names</a>
# * <a href='#row_number_vs_index'>a note on row number vs index</a>
# * <a href='#iloc'>select data by integer Index/position</a>
#
# **advanced data selection**
# * <a href='#conditionalselection'>select data for a given condition or threshold</a>
# * <a href='#conditionalselectionandreturn'>return subset of data for a given condition or threshold</a>
# * <a href='#multicondition'>select data based on multiple conditions or thresholds</a>
#
#
# **Bonus Material**
# (found at end of notebook)
# * <a href='#multioptionlist'> multiple condition options using a list</a>    </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='column_selection'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Column Selection</h4>
#
# **[column selection](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#how-do-i-select-specific-columns-from-a-dataframe)**
#
# <img src="../support_files/images/pandas/pandas_select_columns.png">
#
# to view a single single column
# * <code>df['column_name']</code>    (returns a pandas Series object, which is similar to a 1D array or list)
#
# ~ OR ~
# * <code>df[['column_name']]</code>     (returns a DataFrame)
#
# multiple columns:
# * <code>df[['column_1', 'columns_2']]</code></div>

# %%
# get the Category column as a pd.series

df["Category"]
# Out:
# Row ID
# IN-2014-23218     FURNITURE
# IN-2014-24599     FURNITURE
# IN-2014-24597     FURNITURE
# IN-2014-27993     FURNITURE
# IN-2014-28967     FURNITURE
#                     ...
# ZA-2014-49187    TECHNOLOGY
# ZI-2014-42069    TECHNOLOGY
# ZI-2014-43712    TECHNOLOGY
# ZI-2014-48372    TECHNOLOGY
# ZI-2014-48014    TECHNOLOGY
# Name: Category, Length: 17531, dtype: str

# %%
# get the Category and Customer ID columns 

df[["Category", "Customer ID"]]
# Out:
#                  Category Customer ID
# Row ID
# IN-2014-23218   FURNITURE    AA-10375
# IN-2014-24599   FURNITURE    CA-12055
# IN-2014-24597   FURNITURE    CA-12055
# IN-2014-27993   FURNITURE    GM-14455
# IN-2014-28967   FURNITURE    VB-21745
# ...                   ...         ...
# ZA-2014-49187  TECHNOLOGY    TS-11205
# ZI-2014-42069  TECHNOLOGY     BS-1380
# ZI-2014-43712  TECHNOLOGY     JB-6045
# ZI-2014-48372  TECHNOLOGY     JC-5775
# ZI-2014-48014  TECHNOLOGY     NG-8430
#
# [17531 rows x 2 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='view_vs_copy'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Views vs copies</h4>
#
# We often want to work with only a subset of a dataframe. For that purpose, we can  select only those rows or columns that we need and leave the rest.
#
# Building off of our knowledge of views vs copies that we learned with our numpy tutorial, when we subset an array the result is not always a new array; sometimes what numpy returns is a view of the data in the original array.
# Since pandas Series and DataFrames are backed by numpy arrays, it will probably come as no surprise that something similar sometimes happens in pandas. Unfortunately, while this behavior is relatively straightforward in numpy, in pandas there’s just no getting around the fact that it’s a hot mess.
#
# **The View/Copy Headache in pandas**: In numpy, the rules for when you get views and when you don’t are a little complicated, but they are consistent: certain behaviors (like simple indexing) will always return a view, and others (fancy indexing) will never return a view.
#
# But in pandas, whether you get a view or not—and whether changes made to a view will propagate back to the original DataFrame—depends on the structure and data types in the original DataFrame
#
# <img src="../support_files/images/pandas/pandas_view_vs_copy_b.png">
#
#
# **When to create a copy using <code>[.copy()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.copy.html)</code>**
#
# **Creating copies** of dataframes can be especially useful when doing exploratory analysis on a dataframe where you want to keep the integrity of the original dataframe in case you make a mistake.
#
# <code>new_df = df.copy()</code> makes a copy (by creating a new object) of this object’s indices and data. By default modifications to the data or indices of the copy will not be reflected in the original object but see the documentation and the parameter <code>deep</code> for more information
#
# Note: Like all other variables, try to keep your dataframe naming descriptive and intuitive to read!(For example "new_df" would be a bad name)
# <img src="../support_files/images/pandas/pandas_copy_example_a.png" width='60%'>
# <img src="../support_files/images/pandas/pandas_copy_example_b.png" width='60%'>
#
# </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='loc'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Select rows or columns using labels</h4>
#
# **<code>[.loc()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)</code>** allows access to a group of rows and columns by label(s) or a boolean array.
#
# **select rows:**
# * <code>df.loc['index']</code>
#     * hint: similar to column selection described above, for row selection using df.loc[ ] returns a series where df.loc[[ ]] returns a dataframe
#
#
# **select row and column:**
# * <code>df.loc['index', 'column']</code> </div>

# %%
# get rows where the index is IN-2014-28967

df.loc["IN-2014-28967"]
# Out:
# Order ID                                              IN-2014-47337
# Segment                                                   Corporate
# Category                                                  FURNITURE
# Category (OLD)                                                  NaN
# Sub-Category                                                 CHAIRS
# Product Name                                 Hon Rocking Chair, Red
# Product ID                                          FUR-CH-10003965
# Country                                                 Afghanistan
# Market                                                         APAC
# Region                                                 Central Asia
# Quantity                                                        7.0
# Discount                                                        0.0
# Profit                                                       356.58
# Customer ID                                                VB-21745
# Customer Name                                      Victoria Brennan
# Order Priority                                                 High
# Postal Code                                                     NaN
# Ship Mode                                            Standard Class
# Shipping Cost                                                106.41
# 10/1/2014                                                       NaN
# 7/1/2014                                                        NaN
# 11/1/2014                                                       NaN
# 9/1/2014                                                        NaN
# 1/1/2014                                                        NaN
# 12/1/2014                                                    914.34
# 8/1/2014                                                        NaN
# 5/1/2014                                                        NaN
# 3/1/2014                                                        NaN
# 4/1/2014                                                        NaN
# 2/1/2014                                                        NaN
# 6/1/2014                                                        NaN
# City                                                          Kabul
# State                                                         Kabul
# manufacturers     [ACME Co, Buy n Large, Dunder Mifflin, LexCorp...
# Name: IN-2014-28967, dtype: object

# %%
# get index:ZI-2014-48372 and column'Country'
df.loc["ZI-2014-48372",'Country']
# Out:
# 'Zimbabwe'

# %% [markdown]
# <div class="none" style="">
#
# <a id='iloc'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Select rows and columns by position</h4>
#
# **[.iloc()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html)** allows positional selection ie row number, column number.
#
# (Note that the same slicing notation that we saw with numpy arrays works with `iloc`.)
#
# Example: <code>df.iloc([row(s) number, column(s) number])</code>
#
# Examples:
# * select all rows and all columns
#     * <code>df.iloc[:,:]</code>
# * select first 5 rows and all columns
#     * <code>df.iloc[0:4, :]</code>
# * select all rows and last 5 columns
#     * <code>.iloc[:,-5:]</code></div>

# %%
# get the first 9 rows and all columns
df.iloc[:9,:]
# Out:
#                     Order ID      Segment   Category  Category (OLD)  \
# Row ID
# IN-2014-23218  IN-2014-75456     Consumer  FURNITURE             NaN
# IN-2014-24599  IN-2014-29767  Home Office  FURNITURE             NaN
# IN-2014-24597  IN-2014-29767  Home Office  FURNITURE             NaN
# IN-2014-27993  IN-2014-20415  Home Office  FURNITURE             NaN
# IN-2014-28967  IN-2014-47337    Corporate  FURNITURE             NaN
# AG-2014-50986   AG-2014-2760     Consumer  FURNITURE             NaN
# AG-2014-50983   AG-2014-2760     Consumer  FURNITURE             NaN
# AG-2014-49384   AG-2014-2040     Consumer  FURNITURE             NaN
# AG-2014-47438   AG-2014-2600  Home Office  FURNITURE             NaN
#
#               Sub-Category                     Product Name        Product ID  \
# Row ID
# IN-2014-23218  FURNISHINGS  Rubbermaid Door Stop, Erganomic   FUR-FU-10004064
# IN-2014-24599    BOOKCASES  Ikea Library with Doors, Mobile   FUR-BO-10001255
# IN-2014-24597  FURNISHINGS  Rubbermaid Door Stop, Erganomic   FUR-FU-10004064
# IN-2014-27993    BOOKCASES      Bush Classic Bookcase, Pine   FUR-BO-10002204
# IN-2014-28967       CHAIRS           Hon Rocking Chair, Red   FUR-CH-10003965
# AG-2014-50986  FURNISHINGS  Deflect-O Light Bulb, Erganomic  FUR-DEF-10002865
# AG-2014-50983       CHAIRS     Novimex Rocking Chair, Black  FUR-NOV-10002453
# AG-2014-49384  FURNISHINGS        Rubbermaid Frame, Durable  FUR-RUB-10003004
# AG-2014-47438    BOOKCASES       Ikea 3-Shelf Cabinet, Pine  FUR-IKE-10003642
#
#                    Country  Market        Region  ...  12/1/2014  8/1/2014  \
# Row ID                                            ...
# IN-2014-23218  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-24599  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-24597  Afghanistan    APAC  Central Asia  ...        NaN       NaN
# IN-2014-27993  Afghanistan    APAC  Central Asia  ...        NaN   2070.15
# IN-2014-28967  Afghanistan    APAC  Central Asia  ...     914.34       NaN
# AG-2014-50986      Algeria  Africa        Africa  ...        NaN       NaN
# AG-2014-50983      Algeria  Africa        Africa  ...        NaN       NaN
# AG-2014-49384      Algeria  Africa        Africa  ...        NaN       NaN
# AG-2014-47438      Algeria  Africa        Africa  ...        NaN       NaN
#
#                5/1/2014 3/1/2014 4/1/2014 2/1/2014  6/1/2014     City  State  \
# Row ID
# IN-2014-23218       NaN      NaN      NaN      NaN       NaN    Kabul  Kabul
# IN-2014-24599       NaN   731.82      NaN      NaN       NaN    Herat  Hirat
# IN-2014-24597       NaN   169.68      NaN      NaN       NaN    Herat  Hirat
# IN-2014-27993       NaN      NaN      NaN      NaN       NaN    Kabul  Kabul
# IN-2014-28967       NaN      NaN      NaN      NaN       NaN    Kabul  Kabul
# AG-2014-50986       NaN      NaN      NaN      NaN     17.61    Saida  Saida
# AG-2014-50983       NaN      NaN      NaN      NaN    516.00    Saida  Saida
# AG-2014-49384       NaN      NaN      NaN      NaN       NaN  Algiers  Alger
# AG-2014-47438       NaN      NaN      NaN      NaN       NaN  Algiers  Alger
#
#                                                    manufacturers
# Row ID
# IN-2014-23218  [Dunder Mifflin, Globex Corp, Hudsucker Indust...
# IN-2014-24599  [ACME Co, Buy n Large, Dunder Mifflin, Globex ...
# IN-2014-24597  [Dunder Mifflin, LexCorp, Olivander Crafts, Ro...
# IN-2014-27993                 [Dunder Mifflin, Olivander Crafts]
# IN-2014-28967  [ACME Co, Buy n Large, Dunder Mifflin, LexCorp...
# AG-2014-50986  [ACME Co, Hudsucker Industries, Wayne Enterpri...
# AG-2014-50983             [Dunder Mifflin, Umbrella Corporation]
# AG-2014-49384  [Buy n Large, Hudsucker Industries, LexCorp, R...
# AG-2014-47438  [Buy n Large, Dunder Mifflin, Hudsucker Indust...
#
# [9 rows x 34 columns]

# %%
# get all rows and last 4 columns 
df.iloc[:,-4:]
# Out:
#                6/1/2014      City       State  \
# Row ID
# IN-2014-23218       NaN     Kabul       Kabul
# IN-2014-24599       NaN     Herat       Hirat
# IN-2014-24597       NaN     Herat       Hirat
# IN-2014-27993       NaN     Kabul       Kabul
# IN-2014-28967       NaN     Kabul       Kabul
# ...                 ...       ...         ...
# ZA-2014-49187       NaN     Ndola  Copperbelt
# ZI-2014-42069       NaN  Bulawayo    Bulawayo
# ZI-2014-43712    77.688  Bulawayo    Bulawayo
# ZI-2014-48372       NaN  Bulawayo    Bulawayo
# ZI-2014-48014       NaN    Harare      Harare
#
#                                                    manufacturers
# Row ID
# IN-2014-23218  [Dunder Mifflin, Globex Corp, Hudsucker Indust...
# IN-2014-24599  [ACME Co, Buy n Large, Dunder Mifflin, Globex ...
# IN-2014-24597  [Dunder Mifflin, LexCorp, Olivander Crafts, Ro...
# IN-2014-27993                 [Dunder Mifflin, Olivander Crafts]
# IN-2014-28967  [ACME Co, Buy n Large, Dunder Mifflin, LexCorp...
# ...                                                          ...
# ZA-2014-49187     [ACME Co, Royco Waystar, Umbrella Corporation]
# ZI-2014-42069                                   [Dunder Mifflin]
# ZI-2014-43712       [ACME Co, Buy n Large, Hudsucker Industries]
# ZI-2014-48372                       [ACME Co, Wayne Enterprises]
# ZI-2014-48014  [Dunder Mifflin, Olivander Crafts, Royco Wayst...
#
# [17531 rows x 4 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='conditionalselection'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
#
# <h4>Select data given a specific threshold or condition</h4>
#
# You can conditionally select data using **[.loc[ ]](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)** or **[.query()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html)** or directly on the dataframe. Each of these utilize boolean masking.
#
# <code>.loc</code>
# * <code>df.loc[df['column'] > 7]</code>
# * <code>df.loc[df['column'] == 'string']</code>
#     * Pros: explicit, can be easier to read for those who already know python
#     * cons: more verbose than query
#
# ----
# <code>.query()</code>:
# This method uses boolean expressions and may be easier & more intuitive for those who know sql or other database languages.
#
# Examples:
# * <code>df.query('column > 7')</code>
# * <code>df.query('column == string')</code>
#     * Pros: can be easier for those who know sql or other database languages, less verbose
#     * cons: can be difficult for those that donn't know sql, doesn't hand column names that contain spaces very well   </div>

# %%
# use .loc to select where Profit > 500
df.loc[df['Profit'] > 500]
# Out:
#                      Order ID      Segment    Category  Category (OLD)  \
# Row ID
# IN-2014-27993   IN-2014-20415  Home Office   FURNITURE             NaN
# AO-2014-44396    AO-2014-2270     Consumer   FURNITURE             NaN
# IN-2014-24624   IN-2014-23880     Consumer   FURNITURE             NaN
# IN-2014-31153   IN-2014-80286     Consumer   FURNITURE             NaN
# ID-2014-21496   ID-2014-35892     Consumer   FURNITURE             NaN
# ...                       ...          ...         ...             ...
# CA-2014-33921  CA-2014-127180  Home Office  TECHNOLOGY             NaN
# CA-2014-33920  CA-2014-127180  Home Office  TECHNOLOGY             NaN
# CA-2014-36178  CA-2014-143567    Corporate  TECHNOLOGY             NaN
# CA-2014-37637  CA-2014-143112    Corporate  TECHNOLOGY             NaN
# CA-2014-38429  CA-2014-141439  Home Office  TECHNOLOGY             NaN
#
#               Sub-Category                                       Product Name  \
# Row ID
# IN-2014-27993    BOOKCASES                        Bush Classic Bookcase, Pine
# AO-2014-44396       TABLES          Chromcraft Round Table, Adjustable Height
# IN-2014-24624    BOOKCASES               Sauder Classic Bookcase, Traditional
# IN-2014-31153       CHAIRS  Harbour Creations Executive Leather Armchair, ...
# ID-2014-21496       CHAIRS       SAFCO Executive Leather Armchair, Set of Two
# ...                    ...                                                ...
# CA-2014-33921       PHONES                  Polycom CX600 IP Phone VoIP phone
# CA-2014-33920      COPIERS              Canon imageCLASS 2200 Advanced Copier
# CA-2014-36178  ACCESSORIES                      Logitech diNovo Edge Keyboard
# CA-2014-37637     MACHINES   3D Systems Cube Printer, 2nd Generation, Magenta
# CA-2014-38429       PHONES                             Samsung Galaxy S4 Mini
#
#                      Product ID        Country  Market        Region  ...  \
# Row ID                                                                ...
# IN-2014-27993   FUR-BO-10002204    Afghanistan    APAC  Central Asia  ...
# AO-2014-44396  FUR-CHR-10002278         Angola  Africa        Africa  ...
# IN-2014-24624   FUR-BO-10004852      Australia    APAC       Oceania  ...
# IN-2014-31153   FUR-CH-10000051      Australia    APAC       Oceania  ...
# ID-2014-21496   FUR-CH-10003597      Australia    APAC       Oceania  ...
# ...                         ...            ...     ...           ...  ...
# CA-2014-33921   TEC-PH-10001494  United States      US          East  ...
# CA-2014-33920   TEC-CO-10004722  United States      US          East  ...
# CA-2014-36178   TEC-AC-10004145  United States      US         South  ...
# CA-2014-37637   TEC-MA-10001047  United States      US          East  ...
# CA-2014-38429   TEC-PH-10002624  United States      US       Central  ...
#
#                12/1/2014  8/1/2014  5/1/2014 3/1/2014 4/1/2014 2/1/2014  \
# Row ID
# IN-2014-27993        NaN   2070.15       NaN      NaN      NaN      NaN
# AO-2014-44396        NaN       NaN   1877.16      NaN      NaN      NaN
# IN-2014-24624        NaN       NaN       NaN      NaN      NaN      NaN
# IN-2014-31153        NaN       NaN       NaN      NaN      NaN      NaN
# ID-2014-21496        NaN       NaN       NaN      NaN      NaN      NaN
# ...                  ...       ...       ...      ...      ...      ...
# CA-2014-33921        NaN       NaN       NaN      NaN      NaN      NaN
# CA-2014-33920        NaN       NaN       NaN      NaN      NaN      NaN
# CA-2014-36178        NaN       NaN       NaN      NaN      NaN      NaN
# CA-2014-37637        NaN       NaN       NaN      NaN      NaN      NaN
# CA-2014-38429        NaN       NaN       NaN      NaN      NaN      NaN
#
#                6/1/2014           City              State  \
# Row ID
# IN-2014-27993       NaN          Kabul              Kabul
# AO-2014-44396       NaN         Luanda             Luanda
# IN-2014-24624  3139.128       Mandurah  Western Australia
# IN-2014-31153       NaN     Wollongong    New South Wales
# ID-2014-21496       NaN       Brisbane         Queensland
# ...                 ...            ...                ...
# CA-2014-33921       NaN  New York City           New York
# CA-2014-33920       NaN  New York City           New York
# CA-2014-36178       NaN      Henderson           Kentucky
# CA-2014-37637       NaN  New York City           New York
# CA-2014-38429       NaN       Richmond            Indiana
#
#                                                    manufacturers
# Row ID
# IN-2014-27993                 [Dunder Mifflin, Olivander Crafts]
# AO-2014-44396  [Dunder Mifflin, Globex Corp, LexCorp, Royco W...
# IN-2014-24624  [Buy n Large, Globex Corp, LexCorp, Umbrella C...
# IN-2014-31153  [Globex Corp, LexCorp, Royco Waystar, Umbrella...
# ID-2014-21496  [ACME Co, Buy n Large, Dunder Mifflin, Globex ...
# ...                                                          ...
# CA-2014-33921  [Buy n Large, Dunder Mifflin, Hudsucker Indust...
# CA-2014-33920                                      [Globex Corp]
# CA-2014-36178  [Dunder Mifflin, Globex Corp, Hudsucker Indust...
# CA-2014-37637  [Buy n Large, Hudsucker Industries, LexCorp, O...
# CA-2014-38429  [Hudsucker Industries, LexCorp, Olivander Craf...
#
# [231 rows x 34 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='conditionalselectionandreturn'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
#
# <h4>Return a subset of data given a specific threshold or condition</h4>
#
# You can also return specific columns after doing conditional selection data using **[<code>.loc</code>](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)**.
#
# single return column:
# * <code>df.loc[df['selection_column'] > 7, 'return_column']</code>
#
# multiple return columns (provide columns as a list):
# * <code>df.loc[df['selection_column'] > 7, ['return_column1', 'return_column2']]</code>
# </div>

# %%
# get the Category and Sub-Category where profit is above 500

df.loc[df["Profit"] > 500, ["Category", "Sub-Category"]]
# Out:
#                  Category Sub-Category
# Row ID
# IN-2014-27993   FURNITURE    BOOKCASES
# AO-2014-44396   FURNITURE       TABLES
# IN-2014-24624   FURNITURE    BOOKCASES
# IN-2014-31153   FURNITURE       CHAIRS
# ID-2014-21496   FURNITURE       CHAIRS
# ...                   ...          ...
# CA-2014-33921  TECHNOLOGY       PHONES
# CA-2014-33920  TECHNOLOGY      COPIERS
# CA-2014-36178  TECHNOLOGY  ACCESSORIES
# CA-2014-37637  TECHNOLOGY     MACHINES
# CA-2014-38429  TECHNOLOGY       PHONES
#
# [231 rows x 2 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='multicondition'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
#
# **Multiple condition selection**
#
# You may wish to select rows or columns where multiple conditions are met. You can combine conditions with <code>.loc</code> and like in numpy you will utilize <code>&</code> and <code>|</code>
#
# example:
# <code>df.loc[(df['column1']=='string') & (df['column2'] > threshold)]</code>
#
# </div>

# %%
# return all entries where Profit is greater than 900 and the Sub-Category is "Bookcases"
# the & means both conditions must be met

df.loc[(df['Sub-Category']=="BOOKCASES") & (df['Profit'] >900)]
# Out:
#                       Order ID    Segment   Category  Category (OLD)  \
# Row ID
# IN-2014-24624    IN-2014-23880   Consumer  FURNITURE             NaN
# IN-2014-21263    IN-2014-56206   Consumer  FURNITURE             NaN
# IN-2014-24037    IN-2014-17930   Consumer  FURNITURE             NaN
# IN-2014-28056    IN-2014-66573   Consumer  FURNITURE             NaN
# MX-2014-4452    MX-2014-157077   Consumer  FURNITURE             NaN
# IN-2014-25795    IN-2014-76016  Corporate  FURNITURE             NaN
# IT-2014-16653  IT-2014-4540740   Consumer  FURNITURE             NaN
# ES-2014-12449  ES-2014-4957212   Consumer  FURNITURE             NaN
# ZA-2014-42448     ZA-2014-7540   Consumer  FURNITURE             NaN
#
#               Sub-Category                          Product Name  \
# Row ID
# IN-2014-24624    BOOKCASES  Sauder Classic Bookcase, Traditional
# IN-2014-21263    BOOKCASES        Sauder Classic Bookcase, Metal
# IN-2014-24037    BOOKCASES        Sauder Classic Bookcase, Metal
# IN-2014-28056    BOOKCASES         Bush Classic Bookcase, Mobile
# MX-2014-4452     BOOKCASES   Dania Classic Bookcase, Traditional
# IN-2014-25795    BOOKCASES  Sauder Classic Bookcase, Traditional
# IT-2014-16653    BOOKCASES         Safco Classic Bookcase, Metal
# ES-2014-12449    BOOKCASES           Bush Classic Bookcase, Pine
# ZA-2014-42448    BOOKCASES  Ikea Library with Doors, Traditional
#
#                      Product ID         Country  Market        Region  ...  \
# Row ID                                                                 ...
# IN-2014-24624   FUR-BO-10004852       Australia    APAC       Oceania  ...
# IN-2014-21263   FUR-BO-10001471       Australia    APAC       Oceania  ...
# IN-2014-24037   FUR-BO-10001471           China    APAC    North Asia  ...
# IN-2014-28056   FUR-BO-10004665           China    APAC    North Asia  ...
# MX-2014-4452    FUR-BO-10002300            Cuba   LATAM     Caribbean  ...
# IN-2014-25795   FUR-BO-10004852           India    APAC  Central Asia  ...
# IT-2014-16653   FUR-BO-10004999           Spain      EU         South  ...
# ES-2014-12449   FUR-BO-10004709  United Kingdom      EU         North  ...
# ZA-2014-42448  FUR-IKE-10002894          Zambia  Africa        Africa  ...
#
#                12/1/2014  8/1/2014  5/1/2014 3/1/2014 4/1/2014 2/1/2014  \
# Row ID
# IN-2014-24624        NaN       NaN       NaN      NaN      NaN      NaN
# IN-2014-21263        NaN       NaN       NaN      NaN      NaN      NaN
# IN-2014-24037        NaN       NaN       NaN      NaN      NaN      NaN
# IN-2014-28056        NaN       NaN       NaN      NaN      NaN      NaN
# MX-2014-4452         NaN       NaN       NaN      NaN      NaN      NaN
# IN-2014-25795        NaN       NaN       NaN      NaN      NaN      NaN
# IT-2014-16653    2188.05       NaN       NaN      NaN      NaN      NaN
# ES-2014-12449        NaN       NaN       NaN      NaN      NaN      NaN
# ZA-2014-42448        NaN       NaN       NaN      NaN      NaN      NaN
#
#                6/1/2014                City              State  \
# Row ID
# IN-2014-24624  3139.128            Mandurah  Western Australia
# IN-2014-21263  5486.670              Sydney    New South Wales
# IN-2014-24037       NaN             Qingdao           Shandong
# IN-2014-28056       NaN             Beijing            Beijing
# MX-2014-4452        NaN            Camagüey           Camagüey
# IN-2014-25795       NaN  Thiruvananthapuram             Kerala
# IT-2014-16653       NaN             Seville          Andalusía
# ES-2014-12449       NaN             Burnley            England
# ZA-2014-42448       NaN              Lusaka             Lusaka
#
#                                                    manufacturers
# Row ID
# IN-2014-24624  [Buy n Large, Globex Corp, LexCorp, Umbrella C...
# IN-2014-21263  [ACME Co, Buy n Large, Hudsucker Industries, U...
# IN-2014-24037  [ACME Co, Globex Corp, Hudsucker Industries, O...
# IN-2014-28056  [ACME Co, Buy n Large, Olivander Crafts, Umbre...
# MX-2014-4452   [ACME Co, Buy n Large, Globex Corp, Royco Ways...
# IN-2014-25795  [Buy n Large, Hudsucker Industries, Umbrella C...
# IT-2014-16653  [Globex Corp, Hudsucker Industries, Olivander ...
# ES-2014-12449  [Buy n Large, Globex Corp, LexCorp, Olivander ...
# ZA-2014-42448  [ACME Co, Royco Waystar, Umbrella Corporation,...
#
# [9 rows x 34 columns]

# %%
# return all entries where the Country is "Australia" or the Country is "Zambia"
# the | means at least one condition must be met

df.loc[(df['Country']=="Australia") | (df['Country']=="Zambia")]
# Out:
#                     Order ID      Segment    Category  Category (OLD)  \
# Row ID
# ID-2014-25801  ID-2014-42388     Consumer   FURNITURE             NaN
# IN-2014-21802  IN-2014-25644     Consumer   FURNITURE             NaN
# IN-2014-22521  IN-2014-10090     Consumer   FURNITURE             NaN
# IN-2014-26860  IN-2014-64396  Home Office   FURNITURE             NaN
# ID-2014-30742  ID-2014-84164  Home Office   FURNITURE             NaN
# ...                      ...          ...         ...             ...
# ZA-2014-41769   ZA-2014-1370     Consumer  TECHNOLOGY             NaN
# ZA-2014-45397   ZA-2014-8330    Corporate  TECHNOLOGY             NaN
# ZA-2014-50068   ZA-2014-6660  Home Office  TECHNOLOGY             NaN
# ZA-2014-50069   ZA-2014-6660  Home Office  TECHNOLOGY             NaN
# ZA-2014-49187   ZA-2014-9750    Corporate  TECHNOLOGY             NaN
#
#               Sub-Category                                Product Name  \
# Row ID
# ID-2014-25801  FURNISHINGS                   Deflect-O Frame, Duo Pack
# IN-2014-21802    BOOKCASES                 Bush Corner Shelving, Metal
# IN-2014-22521       CHAIRS  Harbour Creations Steel Folding Chair, Red
# IN-2014-26860  FURNISHINGS              Deflect-O Stacking Tray, Black
# ID-2014-30742  FURNISHINGS                 Tenex Photo Frame, Duo Pack
# ...                    ...                                         ...
# ZA-2014-41769      COPIERS              Brother Personal Copier, Color
# ZA-2014-45397       PHONES                         Cisco Headset, VoIP
# ZA-2014-50068      COPIERS          Brother Fax and Copier, High-Speed
# ZA-2014-50069      COPIERS             Hewlett Fax Machine, High-Speed
# ZA-2014-49187  ACCESSORIES                         Memorex Router, USB
#
#                      Product ID    Country  Market   Region  ...  12/1/2014  \
# Row ID                                                       ...
# ID-2014-25801   FUR-FU-10004780  Australia    APAC  Oceania  ...        NaN
# IN-2014-21802   FUR-BO-10004230  Australia    APAC  Oceania  ...     444.42
# IN-2014-22521   FUR-CH-10001204  Australia    APAC  Oceania  ...        NaN
# IN-2014-26860   FUR-FU-10001129  Australia    APAC  Oceania  ...        NaN
# ID-2014-30742   FUR-FU-10000507  Australia    APAC  Oceania  ...        NaN
# ...                         ...        ...     ...      ...  ...        ...
# ZA-2014-41769  TEC-BRO-10003986     Zambia  Africa   Africa  ...        NaN
# ZA-2014-45397  TEC-CIS-10003439     Zambia  Africa   Africa  ...        NaN
# ZA-2014-50068  TEC-BRO-10003401     Zambia  Africa   Africa  ...        NaN
# ZA-2014-50069  TEC-HEW-10002304     Zambia  Africa   Africa  ...        NaN
# ZA-2014-49187  TEC-MEM-10002202     Zambia  Africa   Africa  ...        NaN
#
#                8/1/2014  5/1/2014 3/1/2014 4/1/2014 2/1/2014  6/1/2014  \
# Row ID
# ID-2014-25801     99.09       NaN      NaN      NaN      NaN       NaN
# IN-2014-21802       NaN       NaN      NaN      NaN      NaN       NaN
# IN-2014-22521       NaN       NaN      NaN   88.101      NaN       NaN
# IN-2014-26860       NaN       NaN      NaN      NaN      NaN     91.26
# ID-2014-30742       NaN       NaN    31.14      NaN      NaN       NaN
# ...                 ...       ...      ...      ...      ...       ...
# ZA-2014-41769       NaN       NaN      NaN      NaN      NaN       NaN
# ZA-2014-45397     88.53       NaN      NaN      NaN      NaN       NaN
# ZA-2014-50068       NaN       NaN      NaN      NaN   189.69       NaN
# ZA-2014-50069       NaN       NaN      NaN      NaN   318.12       NaN
# ZA-2014-49187       NaN       NaN      NaN      NaN   246.42       NaN
#
#                      City            State  \
# Row ID
# ID-2014-25801  Wollongong  New South Wales
# IN-2014-21802    Tamworth  New South Wales
# IN-2014-22521      Sydney  New South Wales
# IN-2014-26860   Bundaberg       Queensland
# ID-2014-30742      Cairns       Queensland
# ...                   ...              ...
# ZA-2014-41769    Chingola       Copperbelt
# ZA-2014-45397      Lusaka           Lusaka
# ZA-2014-50068      Lusaka           Lusaka
# ZA-2014-50069      Lusaka           Lusaka
# ZA-2014-49187       Ndola       Copperbelt
#
#                                                    manufacturers
# Row ID
# ID-2014-25801                             [Hudsucker Industries]
# IN-2014-21802                    [Hudsucker Industries, LexCorp]
# IN-2014-22521  [Buy n Large, Dunder Mifflin, Globex Corp, Oli...
# IN-2014-26860  [ACME Co, Buy n Large, Dunder Mifflin, LexCorp...
# ID-2014-30742        [ACME Co, Dunder Mifflin, Olivander Crafts]
# ...                                                          ...
# ZA-2014-41769  [ACME Co, Hudsucker Industries, Olivander Craf...
# ZA-2014-45397  [Buy n Large, Olivander Crafts, Umbrella Corpo...
# ZA-2014-50068  [Buy n Large, LexCorp, Olivander Crafts, Umbre...
# ZA-2014-50069  [Buy n Large, Globex Corp, Hudsucker Industrie...
# ZA-2014-49187     [ACME Co, Royco Waystar, Umbrella Corporation]
#
# [1023 rows x 34 columns]

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 1) Select Row ID "AG-2014-50983" and all columns
#
# 2) Get the mean profit when the Category is furniture
#
# 3) How many entries in the dataframe are there where "Profit" is negative and "Market" is 'EU'</div>

# %%
# Answer 1:
df.loc["AG-2014-50983"]
# Out:
# Order ID                                    AG-2014-2760
# Segment                                         Consumer
# Category                                       FURNITURE
# Category (OLD)                                       NaN
# Sub-Category                                      CHAIRS
# Product Name                Novimex Rocking Chair, Black
# Product ID                              FUR-NOV-10002453
# Country                                          Algeria
# Market                                            Africa
# Region                                            Africa
# Quantity                                             4.0
# Discount                                             0.0
# Profit                                             61.92
# Customer ID                                      CL-2565
# Customer Name                                Clay Ludtke
# Order Priority                                      High
# Postal Code                                      41244.0
# Ship Mode                                 Standard Class
# Shipping Cost                                      46.75
# 10/1/2014                                            NaN
# 7/1/2014                                             NaN
# 11/1/2014                                            NaN
# 9/1/2014                                             NaN
# 1/1/2014                                             NaN
# 12/1/2014                                            NaN
# 8/1/2014                                             NaN
# 5/1/2014                                             NaN
# 3/1/2014                                             NaN
# 4/1/2014                                             NaN
# 2/1/2014                                             NaN
# 6/1/2014                                           516.0
# City                                               Saida
# State                                              Saida
# manufacturers     [Dunder Mifflin, Umbrella Corporation]
# Name: AG-2014-50983, dtype: object

# %%
# Answer 2 with loc:
df.loc[df['Category']=='FURNITURE', 'Profit'].mean()
# Out:
# np.float64(26.68421359426352)

# %%
# Answer 3
# Return the dataframe where "Profit" is negative and "Market" is 'EU'

# using .loc:
len(df.loc[(df['Profit'] < 0) & (df['Market'] == 'EU')])

# using .query:
len(df.query('Profit < 0 & Market == "EU"'))
# Out:
# 768

# %% [markdown]
# <div class="none" style="">
#
# <a id='manipulate'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h2> Data Manipulations </h2>
#
# <h3> Internal links </h3>
#
# * <a href='#astype'> adjust column type</a>
# * <a href='#addcolumns'> create new columns</a>
#     * <a href='#apply'> .apply()</a>
# * <a href='#dropcolumns'>drop unneccesary or redundant columns</a>
# * <a href='#dropna'>drop nan, NULL entries</a>
# * <a href='#sort_values'>sort the whole dataframe based on one column's values</a>
#
#
# </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='astype'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>change column data type</h4>
#
# After examining your dataframe you may find that there are certain columns whose data types do not match your assumptions or whose data types could inhibit analysis. For example, if you have a column that contains numbers, but the data type is string- you would not actually be able to do numeric operations on it. You can cast the data to a different datatype using  **[.astype()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html)**.
#
# to cast a column to a new data type:
# <code>df['column_1'] = df['column_1'].astype(new type)</code>
#
# remember some of the possible datatypes are:
# * int
# * float64
# * bool
# * string
# </div>

# %%
# we know that in our dataframe quantity should be an integer 
# but right now it's a float- lets change that using .astype()
# then we can check the type after

# change the type to an int
df['Quantity'] = df['Quantity'].astype(int)

# check the data type
df["Quantity"]
# Out:
# Row ID
# IN-2014-23218    2
# IN-2014-24599    2
# IN-2014-24597    4
# IN-2014-27993    5
# IN-2014-28967    7
#                 ..
# ZA-2014-49187    1
# ZI-2014-42069    1
# ZI-2014-43712    1
# ZI-2014-48372    2
# ZI-2014-48014    1
# Name: Quantity, Length: 17531, dtype: int64

# %% [markdown]
# <div class="none" style="">
#
# <a id='addcolumns'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Add new columns</h4>
#
# Frequently you'll want to add **[new columns](https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html)**. There are multiple ways to do this!
#
# <img src="../support_files/images/pandas/pandas_make_new_columns.png">
# to add already computed data:
# * <code>df['new_column_name'] = already_computed_data</code>
#
# You can also calculate new columns based on currently existing columns:
# * <code>df['AB_SUM'] = df['A'] + df['B']</code>
# * <code>df['Volume'] = df['Length'] * df['Height'] * df['Depth']</code>
#
# note: newly created columns are always added to the end of the dataframe
# </div>

# %%
# lets create a "Profit Per Unit" column by diving profit by quantity
df['Profit Per Unit'] = df['Profit'] / df['Quantity']

# now lets view the results
df[["Profit", "Quantity", "Profit Per Unit"]]
# Out:
#                 Profit  Quantity  Profit Per Unit
# Row ID
# IN-2014-23218   39.840         2           19.920
# IN-2014-24599  102.420         2           51.210
# IN-2014-24597   79.680         4           19.920
# IN-2014-27993  848.700         5          169.740
# IN-2014-28967  356.580         7           50.940
# ...                ...       ...              ...
# ZA-2014-49187   19.710         1           19.710
# ZI-2014-42069  -20.799         1          -20.799
# ZI-2014-43712  -59.562         1          -59.562
# ZI-2014-48372  -93.180         2          -46.590
# ZI-2014-48014  -20.298         1          -20.298
#
# [17531 rows x 3 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='apply'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>.apply()</h4>
#
# **[.apply()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html)** is a fairly powerful tool that can do many things. In this context we will use it to create new columns using functions from other packages or functions you've created.
#
# * <code>df['new_column_name'] = df[column(s) of interest].apply(function)</code>
#
# * <code>df['A_sqrt'] = df['A'].apply(np.sqrt)</code>
# * <code>df['A_adjusted'] = df['A'].apply(your_function)</code>
# </div>

# %%
# lets practice by making a function that will fix the capitolization of the 
# Category" column and then applying it

def capitalize_first_letter(string):
    all_lower = string.lower() 
    cap_first = all_lower.capitalize()
    return cap_first

df['Category'] = df['Category'].apply(capitalize_first_letter)

# view the results
df[['Category']]
# Out:
#                  Category
# Row ID
# IN-2014-23218   Furniture
# IN-2014-24599   Furniture
# IN-2014-24597   Furniture
# IN-2014-27993   Furniture
# IN-2014-28967   Furniture
# ...                   ...
# ZA-2014-49187  Technology
# ZI-2014-42069  Technology
# ZI-2014-43712  Technology
# ZI-2014-48372  Technology
# ZI-2014-48014  Technology
#
# [17531 rows x 1 columns]

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 1) In these code examples, what do you think the <code>axis</code> argument is doing?
# What kind of output do you think will be returned? for each?
#
#
# * <code>df[['A', 'B']].apply(np.mean, axis = 0)</code>
# * <code>df[['A', 'B']].apply(np.mean, axis = 1)</code>
#
# 2) Which axis setting is the default? (hint- check the documentation)
# </div>

# %%
### Your answer here:
# Solution 1:
# 0 or 'index': apply function to each column.
# 1 or 'columns': apply function to each row.

# %%
# code to see the output differences 
df[["Quantity", "Profit Per Unit"]].apply(np.sum, axis = 0)
# Out:
# Quantity            60622.00000
# Profit Per Unit    144656.52516
# dtype: float64

# %%
# code to see the output differences 
df[["Quantity", "Profit Per Unit"]].apply(np.sum, axis = 1)
# Out:
# Row ID
# IN-2014-23218     21.920
# IN-2014-24599     53.210
# IN-2014-24597     23.920
# IN-2014-27993    174.740
# IN-2014-28967     57.940
#                   ...
# ZA-2014-49187     20.710
# ZI-2014-42069    -19.799
# ZI-2014-43712    -58.562
# ZI-2014-48372    -44.590
# ZI-2014-48014    -19.298
# Length: 17531, dtype: float64

# %%
### Your answer here:
# Solution 2:
# 0 is the default- meaning it will automatically apply to columns.

# %% [markdown]
# <div class="none" style="">
#
# <a id='lambda'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>lambda functions</h4>
#
# **[lambda](https://www.geeksforgeeks.org/python-lambda-anonymous-functions-filter-map-reduce/#)** is a built in python function that is often used with .apply() for pandas data manipulations.
#
# Python Lambda Functions are anonymous function means that the function is without a name. As we already know that the def keyword is used to define a normal function in Python. Similarly, the lambda keyword is used to define an anonymous function in Python.
#
# * syntactically restricted to a single expression
# * Good for performing short operations/data manipulations
# * generally reduce the readability of code
#
#
# * <code>lambda input_data: data manipulation </code>
# * <code>lambda string: string.lower().capitalize() </code>
#
#
# Defined function:
#
# <code>def cube(num):
#     return num * num * num
# </code>
#
# Lambda equivalent:
#
# <code>lambda num: num * num * num</code>
#
# </div>

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 1) create a lambda function that adds 100 to an input value
#
# </div>

# %%
# solution 1
plus_100 = lambda num: num + 100

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h4>using .apply(lambda)</h4>
#
# **[.apply(lambda)]( https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/#)** is frequently used for row-wise operations, though there are several ways it can be utilized.
#
# In this setting lambda is the function that will be used by .apply
# * <code>data.apply(lambda input: manipulation) </code>
#
# column-wise generic example:
# * <code>df['text column'].apply(lambda string: string.lower().capitalize()) </code>
#
# row-wise generic example:
# * <code>df.apply(lambda row: df['column_A']*df['column_B'], axis = 1) </code>
#
# </div>

# %%
# lets use .apply(lambda) to create a new column that will count the number of manufactuters 
# from the 'manufacturers' column array

df['manufacturers_count'] = df.apply(lambda row : len(row['manufacturers']), axis = 1)

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 1) use <code>.apply(lambda )</code> to apply the <code>capitalize_first_letter function</code> to the 'Sub-Category' column
#
# </div>

# %%
# solution 1
df['Sub-Category'] = df['Sub-Category'].apply(lambda string: capitalize_first_letter(string))

# %% [markdown]
# <div class="none" style="">
#
# <a id='dropcolumns'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Drop specific columns & rows using</h4>
#
# You can easily drop rows or columns using **<code>[.drop()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)</code>**
#
# There are many reasons you may wish to drop columns from your dataframe. Here are a few examples:
# * irrlevant to the analysis you are going to do
# * out of date
# * redundant information
# * non-analyzable due to high rates of Nan or empty entries
#
# drop columns:
# * <code>df = df.drop(columns=['column1', 'columns2'])</code>
# * <code>df = df.drop('column_name',axis=1)</code>
#
# drop rows:
# * <code>df = df.drop(index=('index1_string, 'index2_string'))</code>
# * <code>df = df.drop([row, row])</code></div>

# %%
# Lets drop the 'Category (OLD)'column 
 
df.drop(columns=['Category (OLD)'], inplace=True)

# check the results in the dataframe columns list
df.columns
# Out:
# Index(['Order ID', 'Segment', 'Category', 'Sub-Category', 'Product Name',
#        'Product ID', 'Country', 'Market', 'Region', 'Quantity', 'Discount',
#        'Profit', 'Customer ID', 'Customer Name', 'Order Priority',
#        'Postal Code', 'Ship Mode', 'Shipping Cost', '10/1/2014', '7/1/2014',
#        '11/1/2014', '9/1/2014', '1/1/2014', '12/1/2014', '8/1/2014',
#        '5/1/2014', '3/1/2014', '4/1/2014', '2/1/2014', '6/1/2014', 'City',
#        'State', 'manufacturers', 'Profit Per Unit', 'manufacturers_count'],
#       dtype='str')

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Modifying data inplace</h4>
#
# **<code>[inplace](https://towardsdatascience.com/why-you-should-probably-never-use-pandas-inplace-true-9f9f211849e4#:~:text=Using%20the%20inplace%3DTrue%20keyword,which%20you%20apply%20it%20to.)</code>** is a parameter accepted by a number of pandas methods which affects the behaviour of how the method runs.
# Some examples of where you might commonly see this keyword are the methods(non-exhaustive):
# * <code>[.drop()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html)</code>
# * <code>[.fillna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)</code>
# * <code>[.replace()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html)</code>
# * <code>[.rename()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html)</code>
#
#
# Using the <code>inplace=True</code> keyword in a pandas method changes the default behaviour such that the operation on the dataframe doesn’t return anything, it instead ‘modifies the underlying data’. It mutates the actual object which you apply it to.</div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='dropna'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
#
# <h4>remove rows with missing values</h4>
#
# For columns of particular importance may wish to exclude rows that have missing values to do this we use
# **<code>[.dropna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)</code>**
#
# example:
#     <code>df.dropna(subset=['column'], inplace=bool)</code></div>

# %%
# we will also have an example of this in the next section!

# %% [markdown]
# <div class="none" style="">
#
# <a id='sort_values'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Sort the dataframe based on column values</h4>
#
# **<code>[.sort_values()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)</code>** to sort your dataframe by the the values of a particular column or columns.
#
# <code>df.sort_values(by=['column1', 'column2'], ascending = boolean, inplace= boolean)</code>
#
# pro-tip: Sorting the values of your dataframe before plotting creates more interpretable plots.
#
#
# </div>

# %%
# Lets sort our USA_df by 'Segment', 'Category' and 'Sub-Category' 
# we will leave the underlying data unchanged by setting inpace to False

df.sort_values(by = ['Segment', 'Category', 'Sub-Category'], inplace = False)
# Out:
#                      Order ID      Segment    Category Sub-Category  \
# Row ID
# AG-2014-46003    AG-2014-8600     Consumer   Furniture    Bookcases
# AO-2014-45199    AO-2014-9370     Consumer   Furniture    Bookcases
# US-2014-6344   US-2014-165512     Consumer   Furniture    Bookcases
# US-2014-1158   US-2014-107664     Consumer   Furniture    Bookcases
# IN-2014-21802   IN-2014-25644     Consumer   Furniture    Bookcases
# ...                       ...          ...         ...          ...
# US-2014-40156  US-2014-114356  Home Office  Technology       Phones
# US-2014-33227  US-2014-101539  Home Office  Technology       Phones
# CA-2014-36882  CA-2014-105333  Home Office  Technology       Phones
# ID-2014-26472   ID-2014-41597  Home Office  Technology       Phones
# ID-2014-26474   ID-2014-41597  Home Office  Technology       Phones
#
#                                                  Product Name  \
# Row ID
# AG-2014-46003                   Sauder Classic Bookcase, Pine
# AO-2014-45199                     Bush Classic Bookcase, Pine
# US-2014-6344                   Bush Library with Doors, Metal
# US-2014-1158             Ikea Floating Shelf Set, Traditional
# IN-2014-21802                     Bush Corner Shelving, Metal
# ...                                                       ...
# US-2014-40156  Plantronics Encore H101 Dual Earpieces Headset
# US-2014-33227                    Mitel MiVoice 5330e IP Phone
# CA-2014-36882          Panasonic Business Telephones KX-T7736
# ID-2014-26472                   Nokia Speaker Phone, Cordless
# ID-2014-26474          Samsung Signal Booster, with Caller ID
#
#                      Product ID        Country  Market          Region  \
# Row ID
# AG-2014-46003  FUR-SAU-10002255        Algeria  Africa          Africa
# AO-2014-45199  FUR-BUS-10001243         Angola  Africa          Africa
# US-2014-6344    FUR-BO-10002968      Argentina   LATAM           South
# US-2014-1158    FUR-BO-10001585      Argentina   LATAM           South
# IN-2014-21802   FUR-BO-10004230      Australia    APAC         Oceania
# ...                         ...            ...     ...             ...
# US-2014-40156   TEC-PH-10003171  United States      US           South
# US-2014-33227   TEC-PH-10004165  United States      US            West
# CA-2014-36882   TEC-PH-10001468  United States      US            East
# ID-2014-26472   TEC-PH-10001535        Vietnam    APAC  Southeast Asia
# ID-2014-26474   TEC-PH-10003239        Vietnam    APAC  Southeast Asia
#
#                Quantity  ...  5/1/2014  3/1/2014 4/1/2014 2/1/2014 6/1/2014  \
# Row ID                   ...
# AG-2014-46003         2  ...       NaN       NaN      NaN      NaN      NaN
# AO-2014-45199         2  ...    828.06       NaN      NaN      NaN      NaN
# US-2014-6344          2  ...       NaN  291.0240      NaN      NaN      NaN
# US-2014-1158          4  ...       NaN       NaN      NaN      NaN      NaN
# IN-2014-21802         4  ...       NaN       NaN      NaN      NaN      NaN
# ...                 ...  ...       ...       ...      ...      ...      ...
# US-2014-40156         1  ...       NaN       NaN      NaN      NaN      NaN
# US-2014-33227         3  ...       NaN  659.9760      NaN      NaN      NaN
# CA-2014-36882         3  ...       NaN       NaN      NaN      NaN      NaN
# ID-2014-26472         2  ...       NaN  209.1600      NaN      NaN      NaN
# ID-2014-26474         7  ...       NaN  793.5879      NaN      NaN      NaN
#
#                            City                      State  \
# Row ID
# AG-2014-46003             Batna                      Batna
# AO-2014-45199            Luanda                     Luanda
# US-2014-6344       Buenos Aires               Buenos Aires
# US-2014-1158           La Plata  Provincia de Buenos Aires
# IN-2014-21802          Tamworth            New South Wales
# ...                         ...                        ...
# US-2014-40156         Charlotte             North Carolina
# US-2014-33227           Seattle                 Washington
# CA-2014-36882     New York City                   New York
# ID-2014-26472  Ho Chi Minh City           Ho Chí Minh City
# ID-2014-26474  Ho Chi Minh City           Ho Chí Minh City
#
#                                                    manufacturers  \
# Row ID
# AG-2014-46003       [ACME Co, Globex Corp, Umbrella Corporation]
# AO-2014-45199  [ACME Co, Buy n Large, Globex Corp, Hudsucker ...
# US-2014-6344   [Dunder Mifflin, Globex Corp, Hudsucker Indust...
# US-2014-1158   [Dunder Mifflin, Hudsucker Industries, Royco W...
# IN-2014-21802                    [Hudsucker Industries, LexCorp]
# ...                                                          ...
# US-2014-40156  [ACME Co, Buy n Large, LexCorp, Olivander Craf...
# US-2014-33227  [ACME Co, Royco Waystar, Umbrella Corporation,...
# CA-2014-36882  [LexCorp, Umbrella Corporation, Wayne Enterpri...
# ID-2014-26472  [ACME Co, Hudsucker Industries, Umbrella Corpo...
# ID-2014-26474  [Globex Corp, Hudsucker Industries, LexCorp, O...
#
#                Profit Per Unit  manufacturers_count
# Row ID
# AG-2014-46003          74.3400                    3
# AO-2014-45199         202.8600                    7
# US-2014-6344          -58.2080                    6
# US-2014-1158          -13.6440                    3
# IN-2014-21802          38.2650                    2
# ...                        ...                  ...
# US-2014-40156           3.5960                    6
# US-2014-33227          16.4994                    4
# CA-2014-36882          54.6060                    3
# ID-2014-26472           5.0400                    3
# ID-2014-26474          34.1397                    5
#
# [17531 rows x 35 columns]

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 2) sort the table by profit per unit
# </div>

# %%
# answer 2
df.sort_values(by = 'Profit Per Unit', inplace = False)
# Out:
#                      Order ID      Segment         Category Sub-Category  \
# Row ID
# US-2014-31980  US-2014-168116    Corporate       Technology     Machines
# CA-2014-34308  CA-2014-134845  Home Office       Technology     Machines
# US-2014-36288  US-2014-122714    Corporate  Office supplies      Binders
# CA-2014-34143  CA-2014-152093  Home Office  Office supplies      Binders
# CA-2014-36607  CA-2014-131254     Consumer  Office supplies      Binders
# ...                       ...          ...              ...          ...
# SF-2014-48905    SF-2014-4490     Consumer        Furniture       Tables
# CA-2014-37817  CA-2014-138289     Consumer  Office supplies      Binders
# CA-2014-33920  CA-2014-127180  Home Office       Technology      Copiers
# CA-2014-35487  CA-2014-166709     Consumer       Technology      Copiers
# CA-2014-39450  CA-2014-140151     Consumer       Technology      Copiers
#
#                                                     Product Name  \
# Row ID
# US-2014-31980          Cubify CubeX 3D Printer Triple Head Print
# CA-2014-34308          Lexmark MX611dhe Monochrome Laser Printer
# US-2014-36288               Ibico EPK-21 Electric Binding System
# CA-2014-34143  Fellowes PB500 Electric Punch Plastic Comb Bin...
# CA-2014-36607  Fellowes PB500 Electric Punch Plastic Comb Bin...
# ...                                                          ...
# SF-2014-48905                Bevis Conference Table, Rectangular
# CA-2014-37817          GBC DocuBind P400 Electric Binding System
# CA-2014-33920              Canon imageCLASS 2200 Advanced Copier
# CA-2014-35487              Canon imageCLASS 2200 Advanced Copier
# CA-2014-39450              Canon imageCLASS 2200 Advanced Copier
#
#                      Product ID        Country  Market   Region  Quantity  \
# Row ID
# US-2014-31980   TEC-MA-10004125  United States      US    South         4
# CA-2014-34308   TEC-MA-10000822  United States      US     West         5
# US-2014-36288   OFF-BI-10001120  United States      US  Central         5
# CA-2014-34143   OFF-BI-10003527  United States      US  Central         3
# CA-2014-36607   OFF-BI-10003527  United States      US  Central         6
# ...                         ...            ...     ...      ...       ...
# SF-2014-48905  FUR-BEV-10004805   South Africa  Africa   Africa         2
# CA-2014-37817   OFF-BI-10004995  United States      US  Central         4
# CA-2014-33920   TEC-CO-10004722  United States      US     East         4
# CA-2014-35487   TEC-CO-10004722  United States      US     East         3
# CA-2014-39450   TEC-CO-10004722  United States      US     West         4
#
#                ...  5/1/2014  3/1/2014  4/1/2014 2/1/2014 6/1/2014  \
# Row ID         ...
# US-2014-31980  ...       NaN       NaN       NaN      NaN      NaN
# CA-2014-34308  ...       NaN       NaN  2549.985      NaN      NaN
# US-2014-36288  ...       NaN       NaN       NaN      NaN      NaN
# CA-2014-34143  ...       NaN       NaN       NaN      NaN      NaN
# CA-2014-36607  ...       NaN       NaN       NaN      NaN      NaN
# ...            ...       ...       ...       ...      ...      ...
# SF-2014-48905  ...       NaN       NaN       NaN      NaN      NaN
# CA-2014-37817  ...       NaN       NaN       NaN      NaN      NaN
# CA-2014-33920  ...       NaN       NaN       NaN      NaN      NaN
# CA-2014-35487  ...       NaN       NaN       NaN      NaN      NaN
# CA-2014-39450  ...       NaN  13999.96       NaN      NaN      NaN
#
#                         City           State  \
# Row ID
# US-2014-31980     Burlington  North Carolina
# CA-2014-34308     Louisville        Colorado
# US-2014-36288        Chicago        Illinois
# CA-2014-34143        Chicago        Illinois
# CA-2014-36607        Houston           Texas
# ...                      ...             ...
# SF-2014-48905         George    Western Cape
# CA-2014-37817        Jackson        Michigan
# CA-2014-33920  New York City        New York
# CA-2014-35487         Newark        Delaware
# CA-2014-39450        Seattle      Washington
#
#                                                    manufacturers  \
# Row ID
# US-2014-31980  [ACME Co, Buy n Large, Dunder Mifflin, Globex ...
# CA-2014-34308  [Hudsucker Industries, LexCorp, Olivander Craf...
# US-2014-36288                             [Umbrella Corporation]
# CA-2014-34143             [Buy n Large, Dunder Mifflin, LexCorp]
# CA-2014-36607                             [Buy n Large, LexCorp]
# ...                                                          ...
# SF-2014-48905                                   [Dunder Mifflin]
# CA-2014-37817  [Buy n Large, Hudsucker Industries, LexCorp, O...
# CA-2014-33920                                      [Globex Corp]
# CA-2014-35487  [Buy n Large, Dunder Mifflin, Globex Corp, Hud...
# CA-2014-39450                           [ACME Co, Royco Waystar]
#
#                Profit Per Unit  manufacturers_count
# Row ID
# US-2014-31980        -959.9976                    7
# CA-2014-34308        -679.9960                    4
# US-2014-36288        -585.8969                    1
# CA-2014-34143        -381.2970                    3
# CA-2014-36607        -381.2970                    2
# ...                        ...                  ...
# SF-2014-48905         442.2300                    1
# CA-2014-37817         626.0554                    6
# CA-2014-33920         979.9972                    1
# CA-2014-35487        1679.9952                    8
# CA-2014-39450        1679.9952                    2
#
# [17531 rows x 35 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='plot'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# <h2> Table transformation, aggregation & Plotting </h2>
#
# <h3> Internal links </h3>
#
# * <a href='#wide_vs_long'>Wide vs Long tables</a>
# * <a href='#melt'>transform to a wide dataframe using .melt</a>
# * <a href='#pivot'>transform to a long dataframe using .pivot</a>
#
# * <a href='#crosstab'> get a count of categorical variables with crosstab</a>
# * <a href='#groupby'> aggregate data using .groupby and and get sum using .agg</a>
# * <a href='#pivot_table'> flexible aggregation of categorical variables with .pivot_tabe</a>
#
# NOTE: while this tutorial uses pandas built in plotting functions there are many better packages for plotting, the [Seaborn](https://seaborn.pydata.org/) package workes especially well with pandas dataframe and other tabular style data</div>

# %%
# lets create a new dataframe for this next set of examples
# use .loc[] to select the united states as the country and .copy() to ensure 
# it's a new object and not altering our base dataframe

USA_df = df.loc[df["Country"]=="United States"].copy()

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Resetting the index</h4>
#
# In many of the table transformations, the process of transforming the data changes the index. If we wish to retain the index row we will want to reset the index before we do these transformations so it is saved in a regular column format.
#
# This is easily achievable with **<code>[.reset_index()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html)</code>**.
#
#  * Use <code>drop=True</code> if it's not necessary to maintain a column with the original indexes. </div>

# %%
USA_df.reset_index(inplace=True)

USA_df
# Out:
#              Row ID        Order ID      Segment    Category Sub-Category  \
# 0     CA-2014-39465  CA-2014-107174  Home Office   Furniture       Tables
# 1     CA-2014-39466  CA-2014-107174  Home Office   Furniture       Chairs
# 2     CA-2014-33848  CA-2014-101042     Consumer   Furniture  Furnishings
# 3     CA-2014-32897  CA-2014-158876     Consumer   Furniture  Furnishings
# 4     CA-2014-39961  CA-2014-126634     Consumer   Furniture  Furnishings
# ...             ...             ...          ...         ...          ...
# 3314  US-2014-33227  US-2014-101539  Home Office  Technology       Phones
# 3315  CA-2014-36882  CA-2014-105333  Home Office  Technology       Phones
# 3316  CA-2014-40289  CA-2014-159100    Corporate  Technology  Accessories
# 3317  CA-2014-36007  CA-2014-138149     Consumer  Technology  Accessories
# 3318  US-2014-36486  US-2014-136679     Consumer  Technology  Accessories
#
#                                            Product Name       Product ID  \
# 0                           Hon 5100 Series Wood Tables  FUR-TA-10004575
# 1     Hon 2090 “Pillow Soft” Series Mid Back Swivel/...  FUR-CH-10003312
# 2     3M Polarizing Task Lamp with Clamp Arm, Light ...  FUR-FU-10004665
# 3                     Telescoping Adjustable Floor Lamp  FUR-FU-10001967
# 4                                Flat Face Poster Frame  FUR-FU-10004973
# ...                                                 ...              ...
# 3314                       Mitel MiVoice 5330e IP Phone  TEC-PH-10004165
# 3315             Panasonic Business Telephones KX-T7736  TEC-PH-10001468
# 3316  Memorex Mini Travel Drive 8 GB USB 2.0 Flash D...  TEC-AC-10003499
# 3317  Enermax Briskie RF Wireless Keyboard and Mouse...  TEC-AC-10001284
# 3318                              V7 USB Numeric Keypad  TEC-AC-10004855
#
#             Country Market   Region  ...  5/1/2014  3/1/2014  4/1/2014  \
# 0     United States     US     West  ...       NaN       NaN       NaN
# 1     United States     US     West  ...       NaN       NaN       NaN
# 2     United States     US    South  ...       NaN       NaN       NaN
# 3     United States     US  Central  ...       NaN       NaN       NaN
# 4     United States     US     West  ...       NaN    94.200       NaN
# ...             ...    ...      ...  ...       ...       ...       ...
# 3314  United States     US     West  ...       NaN   659.976       NaN
# 3315  United States     US     East  ...       NaN       NaN       NaN
# 3316  United States     US    South  ...       NaN       NaN       NaN
# 3317  United States     US     West  ...       NaN       NaN       NaN
# 3318  United States     US  Central  ...       NaN       NaN       NaN
#
#      2/1/2014 6/1/2014           City       State  \
# 0         NaN      NaN        Seattle  Washington
# 1         NaN      NaN        Seattle  Washington
# 2         NaN      NaN      Henderson    Kentucky
# 3         NaN      NaN     Carrollton       Texas
# 4         NaN      NaN       Lakewood  California
# ...       ...      ...            ...         ...
# 3314      NaN      NaN        Seattle  Washington
# 3315      NaN      NaN  New York City    New York
# 3316      NaN      NaN       Columbia   Tennessee
# 3317      NaN    62.31    Los Angeles  California
# 3318      NaN      NaN       Pasadena       Texas
#
#                                           manufacturers  Profit Per Unit  \
# 0     [Globex Corp, Umbrella Corporation, Wayne Ente...          52.3764
# 1     [ACME Co, Buy n Large, Globex Corp, Hudsucker ...         -36.5274
# 2     [ACME Co, Globex Corp, Hudsucker Industries, L...          35.6148
# 3       [Dunder Mifflin, Globex Corp, Olivander Crafts]          -6.9965
# 4              [Olivander Crafts, Umbrella Corporation]           7.9128
# ...                                                 ...              ...
# 3314  [ACME Co, Royco Waystar, Umbrella Corporation,...          16.4994
# 3315  [LexCorp, Umbrella Corporation, Wayne Enterpri...          54.6060
# 3316             [Buy n Large, Dunder Mifflin, LexCorp]           2.2002
# 3317              [Royco Waystar, Umbrella Corporation]           7.4772
# 3318  [ACME Co, Globex Corp, Hudsucker Industries, L...          -4.5487
#
#       manufacturers_count
# 0                       3
# 1                       6
# 2                       5
# 3                       3
# 4                       2
# ...                   ...
# 3314                    4
# 3315                    3
# 3316                    3
# 3317                    2
# 3318                    4
#
# [3319 rows x 36 columns]

# %% [markdown]
# <div class="none" style="">
#
# <a id='wide_vs_long'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Wide vs Long dataframes</h4>
#
# <img src="../support_files/images/pandas/pandas_wide_vs_long_df_b.png" width=500/>
#
# **Wide**
#
#
# * methods for creating: <code>df.pivot()</code> and <code>pd.pivot_table(df)</code> can reshape a long dataframe into a wide dataframe
#
# **Long**
#
#
# * methods for creating: <code>pd.melt(df)</code> can reshape a wide dataframe into a long dataframe
#
#
# </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='melt'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>create a long dataframe with .melt()</h4>
#
# **<code>[.melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)</code>** gathers columns into rows.
#
# It can be especially effective if you have several columns related columns containing many nans that would be better represented (and reduce the number of nans) if gathered into rows
#
# <img src="../support_files/images/pandas/pandas_melt.png">
#
#
# <code>df_melt = pd.melt(df, id_vars = [ columns ], value_vars= [ columns ], var_name = string, value_name = string)</code>
#
# * <code>id_vars</code>: Column(s) to use as identifier variables
#     * columns you want to retain/ keep intact)
# * <code>value_vars</code>: Column(s) to unpivot. If not specified, uses all columns that are not set as id_vars.
#     * columns to transform
# * <code>var_name</code>:  Name to use for the ‘variable’ column. If None it uses frame.columns.name or ‘variable’.
#     * what are the columns you want to transform (are they cities? dates? something else?
# * <code>value_name</code>: Name to use for the ‘value’ column.
#     * what are the values of the columns you are going to transform (cost? population? temperature? etc?)
#
# <img src="../support_files/images/pandas/pandas_melt_b.png" width ='60%'>
#
#
#
#
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# In our next example we want to transform our data from wide to long so we can concentrate NaNs to a single column to deal with removing them
#
# <img src="../support_files/images/pandas/pandas_melt_practical_example.png" width ='60%'></div>

# %%
# You may have noticed that there are many missing values in the columns 
# that contain each month, ie "1/1/2014". 
# We will gather these values from columns to rows, creating two new columns

# the variables are the dates and the values represent sales


# the column labels (var_name) all represent order date
# the values(value_name) represent sales

# try to keep your formatting legible by doing like so:
columns_to_keep = ['Row ID','Order ID', 'Segment', 'Category', 'Sub-Category', 'Product Name',
                   'Product ID', 'Country', 'Market', 'Region', 'City', 'State', 
                   'Quantity', 'Discount', 'Profit', 'Customer ID', 'Customer Name',
                    'Order Priority', 'Postal Code', 'Ship Mode', 'Shipping Cost']


columns_to_transform = ['10/1/2014', '7/1/2014', '11/1/2014', '9/1/2014', '1/1/2014',
                        '12/1/2014', '8/1/2014', '5/1/2014', '3/1/2014', '4/1/2014',
                        '2/1/2014', '6/1/2014']

USA_long = pd.melt(USA_df,
                   id_vars = columns_to_keep,
                   value_vars = columns_to_transform,
                   var_name = "Order Date",
                   value_name = "Sales")

# %%
# We can now see the new Dataframe, USA_long
USA_long
# Out:
#               Row ID        Order ID      Segment    Category Sub-Category  \
# 0      CA-2014-39465  CA-2014-107174  Home Office   Furniture       Tables
# 1      CA-2014-39466  CA-2014-107174  Home Office   Furniture       Chairs
# 2      CA-2014-33848  CA-2014-101042     Consumer   Furniture  Furnishings
# 3      CA-2014-32897  CA-2014-158876     Consumer   Furniture  Furnishings
# 4      CA-2014-39961  CA-2014-126634     Consumer   Furniture  Furnishings
# ...              ...             ...          ...         ...          ...
# 39823  US-2014-33227  US-2014-101539  Home Office  Technology       Phones
# 39824  CA-2014-36882  CA-2014-105333  Home Office  Technology       Phones
# 39825  CA-2014-40289  CA-2014-159100    Corporate  Technology  Accessories
# 39826  CA-2014-36007  CA-2014-138149     Consumer  Technology  Accessories
# 39827  US-2014-36486  US-2014-136679     Consumer  Technology  Accessories
#
#                                             Product Name       Product ID  \
# 0                            Hon 5100 Series Wood Tables  FUR-TA-10004575
# 1      Hon 2090 “Pillow Soft” Series Mid Back Swivel/...  FUR-CH-10003312
# 2      3M Polarizing Task Lamp with Clamp Arm, Light ...  FUR-FU-10004665
# 3                      Telescoping Adjustable Floor Lamp  FUR-FU-10001967
# 4                                 Flat Face Poster Frame  FUR-FU-10004973
# ...                                                  ...              ...
# 39823                       Mitel MiVoice 5330e IP Phone  TEC-PH-10004165
# 39824             Panasonic Business Telephones KX-T7736  TEC-PH-10001468
# 39825  Memorex Mini Travel Drive 8 GB USB 2.0 Flash D...  TEC-AC-10003499
# 39826  Enermax Briskie RF Wireless Keyboard and Mouse...  TEC-AC-10001284
# 39827                              V7 USB Numeric Keypad  TEC-AC-10004855
#
#              Country Market   Region  ... Discount    Profit  Customer ID  \
# 0      United States     US     West  ...      0.0  366.6348     AB-10060
# 1      United States     US     West  ...      0.2  -73.0548     AB-10060
# 2      United States     US    South  ...      0.0  213.6888     AB-10105
# 3      United States     US  Central  ...      0.6  -13.9930     AB-10150
# 4      United States     US     West  ...      0.0   39.5640     AB-10165
# ...              ...    ...      ...  ...      ...       ...          ...
# 39823  United States     US     West  ...      0.2   49.4982     VM-21685
# 39824  United States     US     East  ...      0.0  163.8180     VP-21730
# 39825  United States     US    South  ...      0.2    4.4004     VP-21760
# 39826  United States     US     West  ...      0.0   22.4316     WB-21850
# 39827  United States     US  Central  ...      0.2  -27.2922     XP-21865
#
#           Customer Name  Order Priority Postal Code       Ship Mode  \
# 0       Adam Bellavance             Low     98105.0  Standard Class
# 1       Adam Bellavance             Low     98105.0  Standard Class
# 2         Adrian Barton          Medium     42420.0  Standard Class
# 3           Aimee Bixby          Medium     75007.0    Second Class
# 4           Alan Barnes          Medium     90712.0    Second Class
# ...                 ...             ...         ...             ...
# 39823   Valerie Mitchum            High     98105.0    Second Class
# 39824      Victor Preis            High     10011.0  Standard Class
# 39825  Victoria Pisteka          Medium     38401.0  Standard Class
# 39826     William Brown            High     90049.0     First Class
# 39827      Xylona Preis          Medium     77506.0  Standard Class
#
#       Shipping Cost  Order Date  Sales
# 0            524.76   10/1/2014    NaN
# 1             47.81   10/1/2014    NaN
# 2             83.56   10/1/2014    NaN
# 3              1.54   10/1/2014    NaN
# 4              4.69   10/1/2014    NaN
# ...             ...         ...    ...
# 39823         77.64    6/1/2014    NaN
# 39824         64.39    6/1/2014    NaN
# 39825          0.68    6/1/2014    NaN
# 39826         22.06    6/1/2014  62.31
# 39827          8.83    6/1/2014    NaN
#
# [39828 rows x 23 columns]

# %%
# drop rows with empty values in the 'Sales' column
usa_sales_long = USA_long.dropna(subset=['Sales'], inplace = False).copy()

# %%
# Now that we have our long dataframe
# Lets create a new column cost of goods "COGS" 
# we can calculate the cost of goods by by subtracting the profits from the sales
usa_sales_long['COGS'] = USA_long['Sales'] - USA_long['Profit']

# %% [markdown]
# <div class="none" style="">
#
# <a id='pivot'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>create a wide dataframe with .pivot()</h4>
#
# **<code>[.pivot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html)</code>** allows us to transform rows into columns
#
# <img src="../support_files/images/pandas/pandas_pivot.png">
#
# example:
# <code>df.pivot(columns = [ column(s) ])</code>
#
# Parameters:
#
# * <code>columns</code>: Column to use to make new frame’s columns.
# * <code>index</code> (optional): Column to use to make new frame’s index. If None, uses existing index.
# * <code>values</code> (optional): Column(s) to use for populating new frame’s values. If not specified, all remaining columns will be used and the result will have hierarchically indexed columns.
#
# <img src="../support_files/images/pandas/pandas_pivot_b.png" width ='550'> </div>

# %%
# get just the 'state' and 'Category' columns and turn the 'Category' column into rows 
USA_COGS_wide = usa_sales_long.pivot(index = ['Row ID'],
                                     columns='Order Date',
                                     values = 'Sales')

# view the resulting dataframe.
USA_COGS_wide
# Out:
# Order Date     1/1/2014  10/1/2014  11/1/2014  12/1/2014  2/1/2014  3/1/2014  \
# Row ID
# CA-2014-31309       NaN        NaN        NaN        NaN       NaN       NaN
# CA-2014-31331       NaN     29.472        NaN        NaN       NaN       NaN
# CA-2014-31338       NaN        NaN        NaN        NaN       NaN       NaN
# CA-2014-31340       NaN        NaN        NaN        NaN       NaN       NaN
# CA-2014-31368       NaN        NaN        NaN        NaN       NaN       NaN
# ...                 ...        ...        ...        ...       ...       ...
# US-2014-41126       NaN        NaN        NaN        NaN       NaN       NaN
# US-2014-41173       NaN        NaN        NaN        NaN       NaN       NaN
# US-2014-41174       NaN        NaN        NaN        NaN       NaN       NaN
# US-2014-41175       NaN        NaN        NaN        NaN       NaN       NaN
# US-2014-41219       NaN        NaN        NaN        NaN       NaN       NaN
#
# Order Date     4/1/2014  5/1/2014  6/1/2014  7/1/2014  8/1/2014  9/1/2014
# Row ID
# CA-2014-31309    15.552       NaN       NaN       NaN       NaN       NaN
# CA-2014-31331       NaN       NaN       NaN       NaN       NaN       NaN
# CA-2014-31338       NaN       NaN       NaN       NaN       NaN   147.168
# CA-2014-31340       NaN       NaN       NaN       NaN       NaN    95.616
# CA-2014-31368       NaN       NaN       NaN       NaN       NaN    19.050
# ...                 ...       ...       ...       ...       ...       ...
# US-2014-41126       NaN       NaN       NaN   242.352       NaN       NaN
# US-2014-41173   848.544       NaN       NaN       NaN       NaN       NaN
# US-2014-41174     8.700       NaN       NaN       NaN       NaN       NaN
# US-2014-41175   122.382       NaN       NaN       NaN       NaN       NaN
# US-2014-41219       NaN   191.968       NaN       NaN       NaN       NaN
#
# [3319 rows x 12 columns]

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 1) what are some types of plots or analysis that would be facilitated by having a wide form dataframe?
#
# 2) what about a long form dataframe?
#
# </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='crosstab'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4> Aggregate and Get Frequency Counts </h4>
#
#  **<code>[.crosstab()](https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html)</code>** allows you to aggregate by category and get frequency counts.
#
# Cross-tabulations or contingency tables are tables used to describe relationships between two categorical variables. The table displays the frequency distribution of the variables. This is a very easy built in function to use, but the downside is that it is not flexible. It only offers frequency counts.
#
# <code>x_tab = pd.crosstab(index = df[categorical column], columns=df[categorical column])</code>
# * <code>index</code> Values to group by in rows
# * <code>columns</code> Values to group by in columns</div>

# %%
# In this example we want to be able to count number of orders
# by order priority and shipping mode

orders_xtab = pd.crosstab(USA_long['Order Priority'], 
                   columns = USA_long['Ship Mode'])

# view the results
orders_xtab
# Out:
# Ship Mode       First Class  Same Day  Second Class  Standard Class
# Order Priority
# Critical               1368       516           732               0
# High                   3336      1164          3288            5244
# Low                       0         0             0            1956
# Medium                 2172       552          3864           15636

# %% [markdown]
# <div class="none" style="">
#
# <a id='pivot_table'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>aggregate data using .pivot_table()</h4>
#
# **<code>[.pivot_table()](https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html)</code>** allows us to construct quick aggregate tables using categorical variables. This is slightly more complicated than crosstab but it offers more flexibility in aggregator functions.
#
# example:
# <code>pd.pivot_table(df, values = [ ], index = [ ], columns = [ ], aggfunct = )</code>
#
# * <code>values</code>: The column to aggregate (if blank, will aggregate all numerical values)
# * <code>index</code>: The column or columns to group data by. A single column can be a string, while multiple columns should be a list of strings
# * <code>columns</code>: The column or columns to group data by. A single column can be a string, while multiple columns should be a list of strings
# * <code>aggfunc</code>: the type of aggregator function to use, you can use one or many
#     * examples: 'count', 'Mean': np.mean, 'Sigma': np.std</div>

# %%
# To see how this works lets make something similar to our crosstab with counts! 

# Lets use Order ID as our values because it's unique
# set our index to "Order Priority"
# use "Ship Mode" as our columns
# and lets count as our aggregate function to count how many 
# Order IDs there are for each order priorty and shipping mode

pd.pivot_table(USA_long,
               values  = ['Order ID'],
               index   = ['Order Priority'],
               columns = ['Ship Mode'],
               aggfunc = ['count'])
# Out:
#                      count
#                   Order ID
# Ship Mode      First Class Same Day Second Class Standard Class
# Order Priority
# Critical            1368.0    516.0        732.0            NaN
# High                3336.0   1164.0       3288.0         5244.0
# Low                    NaN      NaN          NaN         1956.0
# Medium              2172.0    552.0       3864.0        15636.0

# %%
# Lets do the same thing but with columns that contain values rather than categories. 
# Lets use Sales as our values, and Order Priority and Segment as our index and columns
# we can also get sum and mean at the same time!

pd.pivot_table(USA_long, 
               values  = ['Sales'],
               index   = ['Order Priority'],
               columns = ['Segment'],
               aggfunc = [np.sum, np.mean])
# Out:
#                         sum                                 mean              \
#                       Sales                                Sales
# Segment            Consumer    Corporate Home Office    Consumer   Corporate
# Order Priority
# Critical         15523.3562   13242.7100  12487.2920  147.841488  217.093607
# High            103756.7947   81056.0856  68417.2380  185.944077  263.169109
# Low              12470.4220   12673.7510   7726.4540  148.457405  264.036479
# Medium          200722.4870  135038.6858  70831.7469  216.762945  239.006524
#
#
#
# Segment        Home Office
# Order Priority
# Critical        240.140231
# High            310.987445
# Low             249.240452
# Medium          196.209825

# %% [markdown]
# <div class="none" style="">
#
# <a id='groupby'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>grouping data by category with .groupby()</h4>
#
# **<code>[.groupby()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html</code>)** allows you to group a dataframe using a mapper or by a Series of columns.This can be used to group large amounts of data and compute operations on these groups.
#
#
# <code> grouped_object = df.groupby(by =[columns])</code>
#
# <img src="../support_files/images/pandas/pandas_groupby_object.png" width ='70%'>
#
# Groupby objects are not viewable the same way regular dataframes are. When you create a groupby object in a jupyter notebook the output will look something like so:
# <img src="../support_files/images/pandas/pandas_groupby_object_output.png" width ='70%'>
#
# To access and view individual dataframes/groups from the groupby object you can use
#     **<code>[.get_group()](https://pandas.pydata.org/pandas-docs/version/1.3.2/reference/api/pandas.core.groupby.GroupBy.get_group.html</code>)**
# * <code>grouped_object.get_group('group')</code>
#
#
# <img src="../support_files/images/pandas/pandas_groupby_data_access.png" width ='60%'>
#
# </div>

# %%
# Lets practice creating a groupby object.

# first lets subset usa sales long and group it by region
region_agg = usa_sales_long[['Region', 'Category','COGS']].groupby('Region')

# then we can view the dataframe of one of our region groups
region_agg.get_group('Central')
# Out:
#         Region    Category       COGS
# 55     Central   Furniture   194.2044
# 98     Central   Furniture   420.1578
# 122    Central   Furniture   109.2978
# 123    Central   Furniture  1083.0670
# 425    Central   Furniture   286.7226
# ...        ...         ...        ...
# 39473  Central  Technology    68.0157
# 39728  Central  Technology    78.1868
# 39737  Central  Technology    41.9860
# 39800  Central  Technology   352.9578
# 39801  Central  Technology   407.9400
#
# [778 rows x 3 columns]

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Aggregating and Statistics with groupby</h4>
#
# You can run analytics or further aggregations on each of the groups in your groupby object.
#
# A groupby aggregation operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups. You can use many of the descriptive statistics functions we talked about early in the notebook or **<code>[.agg()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html)</code>** will also compute aggregation on the grouped object.  Example aggregators: min, max, sum, mean, median etc.
#
# * <code>grouped_object.max()</code>
# * <code>grouped_object.agg([aggregator])</code>
#
#
# **Groupby "pipeline":**<br>
# <img src="../support_files/images/pandas/pandas_groupby_pipeline.png">
# </div>

# %%
# This last is gonna be slightly more complicated! 

# Now lets subset the dataframe to just "Region" and "COGS"
COGS_df = usa_sales_long[['Region', 'COGS']]

# Groupby Region and get the sum for each region
region_cogs = COGS_df.groupby(by = 'Region').agg(['sum'])

# Lets view the output dataframe
region_cogs
# Out:
#                 COGS
#                  sum
# Region
# Central  139547.2840
# East     180044.0698
# South    114116.2564
# West     206731.8999

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Adding aggregated data back to original dataframe </h4>
#
# There may be cases where you don't want a whole new dataframe but would just like to add a column of aggregated data back to your original dataframe. In that case the  **<code>[.transform()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transform.html)</code>** function may be useful to you.
#
# <code>df('new_column') = df.groupby(by='category_column')[['data_column']].transform(statistical_function)</code>
#
# **Groupby "pipeline":**<br>
# <img src="../support_files/images/pandas/pandas_groupby_transform.png">
# </div>

# %%
# Final Example! 

# Lets do a similar thing as above (getting cost of goods by reion) but put it back in the original dataframe
usa_sales_long['regional_COGS'] = usa_sales_long.groupby(by = 'Region')[['COGS']].transform(np.sum)

# Lets view the output dataframe (subset it so we can see the relevant columns)
usa_sales_long[["Region", "COGS", "regional_COGS"]]
# Out:
#         Region       COGS  regional_COGS
# 18        East   160.1168    180044.0698
# 19        East    20.3000    180044.0698
# 21        East   254.5008    180044.0698
# 22        East   765.4752    180044.0698
# 38        West   177.7113    206731.8999
# ...        ...        ...            ...
# 39801  Central   407.9400    139547.2840
# 39811     East   167.9790    180044.0698
# 39812    South  2015.9424    114116.2564
# 39813    South   212.9787    114116.2564
# 39826     West    39.8784    206731.8999
#
# [3319 rows x 3 columns]

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
# <p>1) What State has the highest Profit in the US?
# <p>2) Which Customer had the 3rd highest total Sales?
#
# HINT: use the index to easily access sorted data by location</div>

# %%
# Answer 1
# aggregate the correct data & sort it
profit_by_state = USA_long[['State', 'Profit']].groupby('State').agg(['sum'])
profit_by_state.sort_values(by=[('Profit', 'sum')], ascending = False, inplace=True)

# print state with highest profit
print("Most profitable state: " + profit_by_state.index[0])
# Out:
# Most profitable state: California

# %%
# Answer 2

# same process as above
sales_by_cust = USA_long[['Customer Name', 'Sales']].groupby('Customer Name').agg(['sum'])
sales_by_cust.sort_values(by=[('Sales', 'sum')], ascending = False, inplace=True)

# get the 3rd row
print("Customer with 3rd highest total sales: " + sales_by_cust.index[2])
# Out:
# Customer with 3rd highest total sales: Hunter Lopez

# %% [markdown]
# <div class="none" style="">
#
# <a id='table'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h2> Creating, Joining and Saving dataframes </h2>
#
# <h3> Internal links </h3>
#
# **<a href='#create_table'> Creating DataFrames from Scratch:</a>**
# * <a href='#table_from_array'> from an array</a>
# * <a href='#table_from_lists'> from a lists</a>
# * <a href='#table_from_dict'> from a dictionary</a>
#
#
# **Combining DataFrames**
# * <a href='#concat'>append tables with the same structure using .concat</a>
# * <a href='#reset_index'>resetting an index</a>
# * <a href='#merge_df'> merging dataFrames</a>
# * <a href='#merge_left_right'> left and right merges</a>
# * <a href='#merge_inner_outer'> inner and outer merges</a>
#
# **Saving DataFrames**
# * <a href='#save_df'>save to excel</a>
# * <a href='#save_df'>save to .csv</a> </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='create_table'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Creating a DataFrame</h4>
#
# You can create dataframes from scratch by using **<code>[pd.DataFrame()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)</code>**
#
#
# Because dataFrames are tabular, your data will need column names. This usually means that creating a dataframe from scratch will require some combination of using arrays, lists or dictionaries. </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='table_from_array'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# **Create a dataframe from a numpy array**
#
# When creating a dataframe from an array it's important that you know what each dimension of your array represents. Lists and dictionaries are a little more self-documenting in that way, but using arrays can be very efficient.
#
# You must always provide the correct number of column labels to match your array dimensions
# * <code>pd.DataFrame(data_array, columns=['column_1','column_2'...])</code>
#
#
# Note: for this example we will have to create a numpy array (using <code>numpy.random.rand</code>), however in the real world you would already have your array that you'd like to turn into a dataframe.</div>

# %%
# first create the array using numpy random.rand(rows,columns)
data_array = np.random.rand(25,3) 
data_array
# Out:
# array([[0.46845981, 0.01531725, 0.87506836],
#        [0.04783934, 0.49822966, 0.72367016],
#        [0.13192608, 0.09159525, 0.57032123],
#        [0.77492675, 0.46870204, 0.25600813],
#        [0.4059562 , 0.99357483, 0.5515197 ],
#        [0.94879043, 0.94761956, 0.92220782],
#        [0.87573922, 0.79308685, 0.33320491],
#        [0.38340653, 0.84233642, 0.83900468],
#        [0.4580686 , 0.35703183, 0.76313109],
#        [0.49916845, 0.34350673, 0.79567125],
#        [0.65645598, 0.68290167, 0.70431763],
#        [0.04900256, 0.05769039, 0.66995504],
#        [0.2067831 , 0.1276141 , 0.15687852],
#        [0.69705119, 0.84996796, 0.72720372],
#        [0.68633771, 0.57393736, 0.72722575],
#        [0.19524254, 0.94215601, 0.38236403],
#        [0.75007399, 0.79109803, 0.95709234],
#        [0.64604781, 0.12524301, 0.60463905],
#        [0.03469486, 0.67409462, 0.32913723],
#        [0.76513761, 0.63586387, 0.52081574],
#        [0.62215359, 0.86533127, 0.44934589],
#        [0.8235795 , 0.42911804, 0.15235077],
#        [0.45376573, 0.93698693, 0.06354209],
#        [0.13188582, 0.42422725, 0.67211827],
#        [0.09380163, 0.99364129, 0.45307951]])

# %%
# create the dataframe, assigning data first and then the columns
# our array is 25 rows x 3 columns so we must provide 3 column labels
array_df = pd.DataFrame(data_array, columns=['column_1','column_2','column_3'])

#view the dataframe
array_df
# Out:
#     column_1  column_2  column_3
# 0   0.468460  0.015317  0.875068
# 1   0.047839  0.498230  0.723670
# 2   0.131926  0.091595  0.570321
# 3   0.774927  0.468702  0.256008
# 4   0.405956  0.993575  0.551520
# 5   0.948790  0.947620  0.922208
# 6   0.875739  0.793087  0.333205
# 7   0.383407  0.842336  0.839005
# 8   0.458069  0.357032  0.763131
# 9   0.499168  0.343507  0.795671
# 10  0.656456  0.682902  0.704318
# 11  0.049003  0.057690  0.669955
# 12  0.206783  0.127614  0.156879
# 13  0.697051  0.849968  0.727204
# 14  0.686338  0.573937  0.727226
# 15  0.195243  0.942156  0.382364
# 16  0.750074  0.791098  0.957092
# 17  0.646048  0.125243  0.604639
# 18  0.034695  0.674095  0.329137
# 19  0.765138  0.635864  0.520816
# 20  0.622154  0.865331  0.449346
# 21  0.823579  0.429118  0.152351
# 22  0.453766  0.936987  0.063542
# 23  0.131886  0.424227  0.672118
# 24  0.093802  0.993641  0.453080

# %% [markdown]
# <div class="none" style="">
#
# <a id='table_from_lists'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# **dataframe from lists**
#
# You can easily make a dataframe from multiple lists and a dictionary.
# * Each list represents a column of data.
# * dictionary keys represent column names
# * dictionary values are the lists that contain all the data/rows
#
# Note: all lists must be the same length! </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
# For the lists and dictionaries examples we will make a dataframe of adoptable pets! </div>

# %%
# first make the lists, we will have 4 entries for each list
name = ['Oreo','Squid','Mrs Noris', 'Dazzler']
age_months = [5, 18, 12, 9]


# then assign the lists to appropriate column names using dictionary keys
dict_of_lists = {'name': name,
                 'age_months': age_months}

# finally create a dataframe using the dictionary
dict_df1 = pd.DataFrame(dict_of_lists)
dict_df1
# Out:
#         name  age_months
# 0       Oreo           5
# 1      Squid          18
# 2  Mrs Noris          12
# 3    Dazzler           9

# %%
# Another way to make a dataframe using lists and dictionaries is to do the dictionary
# assignment within the dataframe creation call. This just cuts out a middle step

names = ['Cheddar', 'Zuko']
age_months = [7, 21]

dict_df2 = pd.DataFrame({'name':names,
                         'age_months': age_months})
dict_df2
# Out:
#       name  age_months
# 0  Cheddar           7
# 1     Zuko          21

# %% [markdown]
# <div class="none" style="">
#
# <a id='table_from_dict'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# **dataframe from list of dictionaries**
#
# You can also create a single list that contains multiple dictionaries.
# * each dictionary represents a row
# * each key represents a column.
#
# note: you must use the exact same keys in all dictionaries using this method. </div>

# %%
list_of_dicts = [
    {'name': 'Oreo',      'species': 'dog'},
    {'name': 'Dazzler',   'species': 'cat'},
    {'name': 'Templeton', 'species': 'rat'},
]

list_df = pd.DataFrame(list_of_dicts)
list_df
# Out:
#         name species
# 0       Oreo     dog
# 1    Dazzler     cat
# 2  Templeton     rat

# %% [markdown]
# <div class="none" style="">
#
# <a id='concat'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Append dataframes using concat</h4>
#
# you can append one dataframe to another if they have the same structure(i.e. same columns OR same indexes) using **<code>[.concat()](https://pandas.pydata.org/docs/reference/api/pandas.concat.html)</code>**
#
# concatenate rows:
#     <code>pd.concat([df1,df2])</code>
#
# <img src="../support_files/images/pandas/pandas_concat_rows.png">
#
# concatenate columns:
#     <code>pd.concat([df1,df2], axis=1)</code>
#
# <img src="../support_files/images/pandas/pandas_concat_columns.png">
# </div>

# %%
# dict_df1 and dict_df2 have the same structure without redundancy
# so they're good candidates for concatenation. 

pd.concat([dict_df1, dict_df2])
# Out:
#         name  age_months
# 0       Oreo           5
# 1      Squid          18
# 2  Mrs Noris          12
# 3    Dazzler           9
# 0    Cheddar           7
# 1       Zuko          21

# %%
# Lets try concatinating again but resetting the index while we do so

pd.concat([dict_df1, dict_df2]).reset_index(drop=True)
# Out:
#         name  age_months
# 0       Oreo           5
# 1      Squid          18
# 2  Mrs Noris          12
# 3    Dazzler           9
# 4    Cheddar           7
# 5       Zuko          21

# %% [markdown]
# <div class="none" style="">
#
# <a id='merge_df'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Merging DataFrames</h4>
#
# Needing to merge or join dataframes is a very common occurance in data analysis. Frequently one table contains a specific type of data while another table contains some other data, and you wish to combine that information.
#
# There are several different ways to merge DataFrames. The most common way is using **<code>[.merge()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)</code>**
#
# Important function arguments:
# * <code>how</code> determines the way the dataframes are merged. There are 4 basic options:
#     * <code>'left'</code> & <code>'right'</code>
#     * <code>'inner'</code>(default) & <code>'outer'</code>
#
# * <code>on</code> argument identifies which column(s) are common across both dataframes and should be used as the index to merge the dataframes on
#     * in the example images below 'x1' is the common column that would be used
#         * <code>on ='x1'</code></div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='merge_left_right'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Left and Right merges</h4>
#
# For <code>'left'</code> and <code>'right'</code> merges, the order that you list the dataframes in the <code>.merge()</code> function matters. The first dataframe listed is the 'left' dataframe and the second is the 'right' dataframe.
#
# * left merge:
#     * Joins matching rows from df_right to df_left, retaining all the information from the df_left.
#     * <code>left_merge_df = pd.merge(df_left, df_right, how='left', on='x1')</code>
#
# <img src="../support_files/images/pandas/pandas_join_left.png">
#
# * right merge example:
#     * Joins matching rows from df_left to df_right, retaining all the information from the df_right
#     * <code>right_merge_df = pd.merge(left_df, right_df, how='right', on='x1')</code>
#
# <img src="../support_files/images/pandas/pandas_join_right.png">
# </div>

# %%
# Lets do a LEFT join 
# dict_df1 which contains information on animal 'name' and 'age_months'
# list_df contains 'name' and 'species'

pd.merge(dict_df1, list_df, how = 'left', on ='name')
# Out:
#         name  age_months species
# 0       Oreo           5     dog
# 1      Squid          18     NaN
# 2  Mrs Noris          12     NaN
# 3    Dazzler           9     cat

# %%
# Try a right join with the same dataframes! 

pd.merge(dict_df1, list_df, how = 'right', on ='name')
# Out:
#         name  age_months species
# 0       Oreo         5.0     dog
# 1    Dazzler         9.0     cat
# 2  Templeton         NaN     rat

# %% [markdown]
# <div class="none" style="">
#
# <a id='merge_inner_outer'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4>Inner and Outer Merges</h4>
#
# For <code>'inner'</code> and <code>'outer'</code> merges, the order of the dataframes does not matter. Instead the inner and outer merges are based on what is common between both dataframes.
#
# * inner merge:
#     * Join data and retains only rows found in both dataframes.
#     * <code>inner_merge_df = pd.merge(df1, df2, how='inner', on='x1')</code>
#
# <img src="../support_files/images/pandas/pandas_join_inner.png">
#
# * outer merge:
#     * Joins dataframes and retains all values, all rows.
#     * <code>outer_merge_df = pd.merge(df1, df2, how='outer', on='x1')</code>
#
# <img src="../support_files/images/pandas/pandas_join_outer.png"> </div>

# %%
# Lets try an outer merge with those same dataframes

pd.merge(dict_df1, list_df, how = 'outer', on ='name')
# Out:
#         name  age_months species
# 0    Dazzler         9.0     cat
# 1  Mrs Noris        12.0     NaN
# 2       Oreo         5.0     dog
# 3      Squid        18.0     NaN
# 4  Templeton         NaN     rat

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# <h4> Merging with Indexes</h4>
#
# You may have two tables that you'd like to merge where the index of one dataframe is a column in another dataframe.
#
# <img src="../support_files/images/pandas/pandas_index_merge.png">
#
# <code>df1.merge(df2, left_on = "x3", right_index = True)</code>
#
# **Parameters:**
#
# <code>left_on</code> label or list, or array-like
# Column or index level names to join on in the left DataFrame. Can also be an array or list of arrays of the length of the left DataFrame. These arrays are treated as if they are columns.
#
# <code>right_on</code> label or list, or array-like
# Column or index level names to join on in the right DataFrame. Can also be an array or list of arrays of the length of the right DataFrame. These arrays are treated as if they are columns.
#
# <code>left_index</code> bool, default False
# Use the index from the left DataFrame as the join key(s). If it is a MultiIndex, the number of keys in the other DataFrame (either the index or a number of columns) must match the number of levels.
#
# <code>right_index</code> bool, default False
# Use the index from the right DataFrame as the join key. Same caveats as left_index.
#
# NOTE: If you have other columns in common besides the merging column/index these will appear twice in your new dataframe! </div>

# %% [markdown]
# <div class="none" style="">
#
# <a id='save_df'></a>
# </div>

# %% [markdown]
# <div class="default" style="border-left: 3px solid #000; padding: 1px; padding-left: 10px; background: #F0FAFF; color: #000;">
#
# **Saving dataframes**
#
# Just like loading dataframes, there are many different formats that you can save a dataframe to. We will just show you .csv and .xls but to see a complete list please check out the [input/output documentation here](https://pandas.pydata.org/docs/reference/io.html):
#
# * [.to_csv()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)
#     * <code>df.to_csv('df_save_name.csv')</code>
#
# * [.to_excel()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html#pandas.DataFrame.to_excel)
#     * <code>df.to_excel('df_save_name.xlsx')</code>
#
#
# by default the save functions will save to your working directory. You must specify a path if you wish to save your dataframe elsewhere.
#
#
# </div>

# %% [markdown]
# <div class="exercise" style="background: #DFF0D8; border-radius: 3px; padding: 10px; color: #000;">
#
# **STUDENT EXERCISES:**
#
# 1) Read in population data from the csv file and show the columns (find file in: ../support_files/datasets/population_by_country_2020.csv).
#
# 2) Perform a left merge on the original dataframe (df) and new population population dataframe, using "Country" column, print columns to confirm merge
#
# 3) Return the merged dataframe from "Country" with the highest population, first 10 rows
#
# This country population dataset was provided mostly as an example for you to trying merging two diffeferent datasets. But feel free to consider interesting questions and corresponding plots to investigate this merged data. For example, is there a difference in categories of items sold in high vs low population countries?</div>

# %%
# Answer 1:
filepath = os.path.join('../support_files', 'datasets', 'population_by_country_2020.csv')

pop_df = pd.read_csv(filepath)

print(pop_df.columns)
# Out:
# Index(['Country', 'Population', 'Yearly Change', 'Net Change',
#        'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)', 'Fert. Rate',
#        'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='str')

# %%
# Answer 2:
merged_df  = pd.merge(df, pop_df, how = 'left', on ='Country')
print(merged_df.columns)
# Out:
# Index(['Order ID', 'Segment', 'Category', 'Sub-Category', 'Product Name',
#        'Product ID', 'Country', 'Market', 'Region', 'Quantity', 'Discount',
#        'Profit', 'Customer ID', 'Customer Name', 'Order Priority',
#        'Postal Code', 'Ship Mode', 'Shipping Cost', '10/1/2014', '7/1/2014',
#        '11/1/2014', '9/1/2014', '1/1/2014', '12/1/2014', '8/1/2014',
#        '5/1/2014', '3/1/2014', '4/1/2014', '2/1/2014', '6/1/2014', 'City',
#        'State', 'manufacturers', 'Profit Per Unit', 'manufacturers_count',
#        'Population', 'Yearly Change', 'Net Change', 'Density (P/Km²)',
#        'Land Area (Km²)', 'Migrants (net)', 'Fert. Rate', 'Med. Age',
#        'Urban Pop %', 'World Share'],
#       dtype='str')

# %%
# Answer 3:
merged_df.sort_values(by=['Population'], ascending = False).head(10)
merged_df
# Out:
#             Order ID      Segment    Category Sub-Category  \
# 0      IN-2014-75456     Consumer   Furniture  Furnishings
# 1      IN-2014-29767  Home Office   Furniture    Bookcases
# 2      IN-2014-29767  Home Office   Furniture  Furnishings
# 3      IN-2014-20415  Home Office   Furniture    Bookcases
# 4      IN-2014-47337    Corporate   Furniture       Chairs
# ...              ...          ...         ...          ...
# 17526   ZA-2014-9750    Corporate  Technology  Accessories
# 17527   ZI-2014-7610    Corporate  Technology     Machines
# 17528   ZI-2014-5970  Home Office  Technology  Accessories
# 17529   ZI-2014-9550     Consumer  Technology     Machines
# 17530   ZI-2014-3570     Consumer  Technology     Machines
#
#                           Product Name        Product ID      Country  Market  \
# 0      Rubbermaid Door Stop, Erganomic   FUR-FU-10004064  Afghanistan    APAC
# 1      Ikea Library with Doors, Mobile   FUR-BO-10001255  Afghanistan    APAC
# 2      Rubbermaid Door Stop, Erganomic   FUR-FU-10004064  Afghanistan    APAC
# 3          Bush Classic Bookcase, Pine   FUR-BO-10002204  Afghanistan    APAC
# 4               Hon Rocking Chair, Red   FUR-CH-10003965  Afghanistan    APAC
# ...                                ...               ...          ...     ...
# 17526              Memorex Router, USB  TEC-MEM-10002202       Zambia  Africa
# 17527              StarTech Phone, Red  TEC-STA-10000699     Zimbabwe  Africa
# 17528               Belkin Router, USB  TEC-BEL-10003985     Zimbabwe  Africa
# 17529      Konica Receipt Printer, Red  TEC-KON-10003116     Zimbabwe  Africa
# 17530          Okidata Calculator, Red  TEC-OKI-10001433     Zimbabwe  Africa
#
#              Region  Quantity  ...  Population  Yearly Change Net Change  \
# 0      Central Asia         2  ...  39074280.0         2.33 %   886592.0
# 1      Central Asia         2  ...  39074280.0         2.33 %   886592.0
# 2      Central Asia         4  ...  39074280.0         2.33 %   886592.0
# 3      Central Asia         5  ...  39074280.0         2.33 %   886592.0
# 4      Central Asia         7  ...  39074280.0         2.33 %   886592.0
# ...             ...       ...  ...         ...            ...        ...
# 17526        Africa         1  ...  18468257.0         2.93 %   522925.0
# 17527        Africa         1  ...  14899771.0         1.48 %   217456.0
# 17528        Africa         1  ...  14899771.0         1.48 %   217456.0
# 17529        Africa         2  ...  14899771.0         1.48 %   217456.0
# 17530        Africa         1  ...  14899771.0         1.48 %   217456.0
#
#       Density (P/Km²) Land Area (Km²)  Migrants (net) Fert. Rate  Med. Age  \
# 0                60.0        652860.0        -62920.0        4.6        18
# 1                60.0        652860.0        -62920.0        4.6        18
# 2                60.0        652860.0        -62920.0        4.6        18
# 3                60.0        652860.0        -62920.0        4.6        18
# 4                60.0        652860.0        -62920.0        4.6        18
# ...               ...             ...             ...        ...       ...
# 17526            25.0        743390.0         -8000.0        4.7        18
# 17527            38.0        386850.0       -116858.0        3.6        19
# 17528            38.0        386850.0       -116858.0        3.6        19
# 17529            38.0        386850.0       -116858.0        3.6        19
# 17530            38.0        386850.0       -116858.0        3.6        19
#
#        Urban Pop %  World Share
# 0             25 %       0.50 %
# 1             25 %       0.50 %
# 2             25 %       0.50 %
# 3             25 %       0.50 %
# 4             25 %       0.50 %
# ...            ...          ...
# 17526         45 %       0.24 %
# 17527         38 %       0.19 %
# 17528         38 %       0.19 %
# 17529         38 %       0.19 %
# 17530         38 %       0.19 %
#
# [17531 rows x 45 columns]
